# %%
import json
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
def obtenerTweetsConTexto (ficheroTweets):
    import json
    fichero = open(ficheroTweets)
    # Devuelve una lista de diccionarios solo con los elementos a analizar 
    # (aquellos que tengan key 'text')
    tweetsDatos = fichero.readlines()
    # Tras leer el fichero, tenemos una lista de textos con formato JSON que podemos
    # descomponer. Asumimos que cada id de tweeter es unico por lo que puede usarse
    # como clave en un diccionario final:
    tweetsAnalizar = {}
    for tweet in tweetsDatos:
        try: jsonDict = json.loads(tweet)
        except: jsonDict = None
        if 'text' in jsonDict.keys():
            tweetsAnalizar[jsonDict['id']]=jsonDict['text'] 
    return tweetsAnalizar

def obtenerSentimientos(ficheroSentimientos):
    fichero = open(ficheroSentimientos)
    listaSentimientos = fichero.readlines()
    # Basandonos en la estructura, en cada elemento de la lista hay una cadena de dos
    # palabras separadas por un tabulador \t --> Generamos un diccionario para 
    # explotarlo mejor
    sentimientosDict = {}
    for sentimiento in listaSentimientos:
        listaFila = sentimiento.split('\t')
        sentimientosDict[listaFila[0]] = int(listaFila[1])
    return sentimientosDict

# %%
ficheroTweets = '/home/chema/MasterBI/practicas/01.Fundamentos/salida_tweets.txt'
ficheroSentimientos = '/home/chema/MasterBI/practicas/01.Fundamentos/Sentimientos.txt'
tweetsAnalizar = obtenerTweetsConTexto (ficheroTweets)
print(tweetsAnalizar)
kk = obtenerSentimientos(ficheroSentimientos)
print(kk)
# pythonDatos['id']
# pythonDatos['text']
# Out:
# {509748524897292288: '@Brenamae_ I WHALE SLAP YOUR FIN AND TELL YOU ONE LAST TIME: GO AWHALE', 509748529070616576: 'Metin Şentürk Twitterda @metinsenturk MUHTEŞEM ÜÇLÜ; SEN, BEN, MÜZİK', 509748529095774208: 'RT @byunghns: 😭 I LOVE #틴탑 SO MUCH #쉽지않아 IS GOING TO BE SO GOOD 😭', 509748529104175104: 'que hdp maicon lo que le hizo a david luiz jajajajajajajajajajaj,igual se jodio la carrera', 509748529107988480: 'ドライ！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！', 509748529074814976: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529074827266: 'RT @GossipRoomOff: Si Nathalie sait pertinemment que son couple ne va pas durer, alors pourquoi accepter la demande en mariage de Vivian ? …', 509748529083211776: 'RT @Dayannalozano_: Junior va perdiendo... http://t.co/5mOsR7boLx', 509748529074823170: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529087397889: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529104191488: 'الله أكبر الله أكبر الله أكبر, لا إله إلا الله, الله أكبر الله اكبر ولله الحمد http://t.co/M454OhQpYY', 509748529074827267: "TWİTTER'I AKRABALAR KEŞFEDİCEK DİYE ÇOK KORKUYORUM \n Metin Şentürk Twitterda @metinsenturk", 509748529070632960: 'RT @PINKBATHARRY: les saintes nitouches de ma classe qui aiment les 5sos si je leur montre le vine de la bite a calum on verra si elles son…', 509748529104162816: "RT @le_Parisien: Ebola\xa0: des pilotes d'Air France refusent les vols vers les pays touchés http://t.co/lt37QKDwr2", 509748529087381504: "@hailee_danielsx I'm not mean cuz I'm ugly so ya", 509748529070612481: 'You better believe your beautiful', 509748529083191296: "RT @baileymac02: CAN'T WAIT! I am playing @SoccerSix at The London Soccerdome on SUNDAY 26TH OCTOBER! Tickets selling fast: http://t.co/c6i…", 509748529079009280: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529074417666: 'ドラコ・マルフォイ\u3000「闇の帝王が支配なさる時、OWLやNEWTが何科目なんて『あの人』が気になさるか？もちろん、そんなことは問題じゃない・・・『あの人』のためにどのように奉仕し、どのような献身ぶりを示して来たかだけが重要だ」', 509748529086996481: 'RT @reading_bot_: 마주앉는다는 것은 눈으로 보기를 좋아한다는 것이다.\n옆에 앉는다는 것은 손으로 만지기를 좋아한다는 것이다.\n그러니까 남자들은 시각 중심적이고\n여자들은 촉각 혹은 후각 중심적이다.\n(이문재, 아주 낯선 낯익은 이야기)', 509748529074417665: 'RT @En7raaF69: عبودي من الرياض ينآك آآح يالدلع\n\nhttp://t.co/HS1h0xwPAo\n\n#افلام_سكس #ممحونه #ورعان #سكس #ديوث #سالب #قحبه #خلفي #فلم #محارم …', 509748529095389184: 'Vince Staples so cold', 509748529095782400: '@Chinamiiii721 \n\n球児？\nわからんか\n\nもう一人の方は？あのギャル見たいな子', 509748529079005184: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529074413568: "'", 509748529087397891: '#AbrahamMateoEnCanalFiesta @dominguezja Necesito que me susure al oido, abrazarlo, sentir su calor.. TODO LO QUE SIEMPRE E DESEADO!.P', 509748529074810880: '@AppIe_France mais ne vs sentez pas agressé, même non officiel votre compte est intéressant car rassemble les différentes infos.', 509748529074827265: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529087406080: 'http://t.co/Chp71M0uCe', 509748529087393792: "RT @Nashgrier: Happy Birthday to one of my best friends @jackgilinsky Can't wait till you're out in LA! Have a good one!", 509748529070219264: 'I liked a @YouTube video from @jordzcreations http://t.co/YJhzCimXHG TOP 5 RATED PLAYERS IN FIFA15! (MESSI, RONALDO &amp; IBRA!)', 509748529108361217: 'RT @KirkJTorrance: Cat\'s out of the bag! "@WilliamJHague: giving Scotland more powers if it votes No is not Government policy" http://t.co/…', 509748529082814464: 'RT @NASA: Roiling flows of lava on Holuhraun Lava Field seen by @NASA_Landsat in Iceland: http://t.co/3ogFKIvcfv #EarthRightNow http://t.co…', 509748529070239744: '続編きたあああ\u3000 #prismaillya', 509748529091207168: '"@jaureguisteam: VOU TER QUE COMEÇAR COM AS AMEAÇAS  #MTVEMA #NominateFifthHarmony"', 509748529070612480: 'http://t.co/EMQdW8bhKx', 509748529082806272: 'RT @PBirdly: Just setting up my Twitter. #myfirstTweet', 509748529070624768: 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 509748529078616064: 'RT @ ...
# {'abandon': -2, 'abandoned': -2, 'abandons': -2, 'abducted': -2, 'abduction': -2, 'abductions': -2, 'abhor': -3, 'abhorred': -3, 'abhorrent': -3, 'abhors': -3, 'abilities': 2, 'ability': 2, 'aboard': 1, 'absentee': -1, 'absentees': -1, 'absolve': 2, 'absolved': 2, 'absolves': 2, 'absolving': 2, 'absorbed': 1, 'abuse': -3, 'abused': -3, 'abuses': -3, 'abusive': -3, 'accept': 1, 'accepted': 1, 'accepting': 1, 'accepts': 1, 'accident': -2, 'accidental': -2, 'accidentally': -2, 'accidents': -2, 'accomplish': 2, 'accomplished': 2, 'accomplishes': 2, 'accusation': -2, 'accusations': -2, 'accuse': -2, 'accused': -2, 'accuses': -2, 'accusing': -2, 'ache': -2, 'achievable': 1, 'aching': -2, 'acquit': 2, 'acquits': 2, 'acquitted': 2, 'acquitting': 2, 'acrimonious': -3, 'active': 1, 'adequate': 1, 'admire': 3, 'admired': 3, 'admires': 3, 'admiring': 3, 'admit': -1, 'admits': -1, 'admitted': -1, 'admonish': -2, 'admonished': -2, 'adopt': 1, 'adopts': 1, 'adorable': 3, 'adore': 3, 'adored': 3, 'adores': 3, 'advanced': 1, 'advantage': 2, 'advantages': 2, 'adventure': 2, 'adventures': 2, 'adventurous': 2, 'affected': -1, 'affection': 3, 'affectionate': 3, 'afflicted': -1, 'affronted': -1, 'afraid': -2, 'aggravate': -2, 'aggravated': -2, 'aggravates': -2, 'aggravating': -2, 'aggression': -2, 'aggressions': -2, 'aggressive': -2, 'aghast': -2, 'agog': 2, 'agonise': -3, 'agonised': -3, 'agonises': -3, 'agonising': -3, 'agonize': -3, 'agonized': -3, 'agonizes': -3, 'agonizing': -3, 'agree': 1, 'agreeable': 2, 'agreed': 1, 'agreement': 1, 'agrees': 1, 'alarm': -2, 'alarmed': -2, 'alarmist': -2, 'alarmists': -2, 'alas': -1, 'alert': -1, 'alienation': -2, 'alive': 1, 'allergic': -2, 'allow': 1, 'alone': -2, 'amaze': 2, 'amazed': 2, 'amazes': 2, 'amazing': 4, 'ambitious': 2, 'ambivalent': -1, 'amuse': 3, 'amused': 3, 'amusement': 3, 'amusements': 3, 'anger': -3, 'angers': -3, 'angry': -3, 'anguish': -3, 'anguished': -3, 'animosity': -2, 'annoy': -2, 'annoyance': -2, 'annoyed': -2, 'annoying': -2, 'annoys': -2, 'antagonistic': -2, 'anti': -1, 'anticipation': 1, 'anxiety': -2, 'anxious': -2, 'apathetic': -3, 'apathy': -3, 'apeshit': -3, 'apocalyptic': -2, 'apologise': -1, 'apologised': -1, 'apologises': -1, 'apologising': -1, 'apologize': -1, 'apologized': -1, 'apologizes': -1, 'apologizing': -1, 'apology': -1, 'appalled': -2, 'appalling': -2, 'appease': 2, 'appeased': 2, 'appeases': 2, 'appeasing': 2, 'applaud': 2, 'applauded': 2, 'applauding': 2, 'applauds': 2, 'applause': 2, 'appreciate': 2, 'appreciated': 2, 'appreciates': 2, 'appreciating': 2, 'appreciation': 2, 'apprehensive': -2, 'approval': 2, 'approved': 2, 'approves': 2, 'ardent': 1, 'arrest': -2, 'arrested': -3, 'arrests': -2, 'arrogant': -2, 'ashame': -2, 'ashamed': -2, 'ass': -4, 'assassination': -3, 'assassinations': -3, 'asset': 2, 'assets': 2, 'assfucking': -4, 'asshole': -4, 'astonished': 2, 'astound': 3, 'astounded': 3, 'astounding': 3, 'astoundingly': 3, 'astounds': 3, 'attack': -1, 'attacked': -1, 'attacking': -1, 'attacks': -1, 'attract': 1, 'attracted': 1, 'attracting': 2, 'attraction': 2, 'attractions': 2, 'attracts': 1, 'audacious': 3, 'authority': 1, 'avert': -1, 'averted': -1, 'averts': -1, 'avid': 2, 'avoid': -1, 'avoided': -1, 'avoids': -1, 'await': -1, 'awaited': -1, 'awaits': -1, 'award': 3, 'awarded': 3, 'awards': 3, 'awesome': 4, 'awful': -3, 'awkward': -2, 'axe': -1, 'axed': -1, 'backed': 1, 'backing': 2, 'backs': 1, 'bad': -3, 'badass': -3, 'badly': -3, 'bailout': -2, 'bamboozle': -2, 'bamboozled': -2, 'bamboozles': -2, 'ban': -2, 'banish': -1, 'bankrupt': -3, 'bankster': -3, 'banned': -2, 'bargain': 2, 'barrier': -2, 'bastard': -5, 'bastards': -5, 'battle': -1, 'battles': -1, 'beaten': -2, 'beatific': 3, 'beating': -1, 'beauties': 3, 'beautiful': 3, 'beautifully': 3, 'beautify': 3, 'belittle': -2, 'belittled': -2, 'beloved': 3, 'benefit': 2, 'benefits': 2, 'benefitted': 2, 'benefitting': 2, 'bereave': -2, 'bereaved': -2, 'bereaves': -2, 'bereaving': -2, 'best': 3, 'be ...
