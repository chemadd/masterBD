# %%
strBuscar = 'ra'
palabra = 'palabra'
lista = []
lista = lista + ['kk 5'] + ['kk 5']
print (lista)
print(str(len(palabra)) + ' ' + str(len(palabra) - len(strBuscar)))
print(str(palabra.find(strBuscar, len(palabra) - len(strBuscar), len(palabra))))
# Out:
# ['kk 5', 'kk 5']
# 7 5
# 5

# %%
def obtenerTweetsConTexto (ficheroTweets):
    import json
    fichero = open(ficheroTweets)
    # Devuelve una lista de diccionarios solo con los elementos a analizar 
    # (aquellos que tengan key 'text')
    tweetsDatos = fichero.readlines()
    # Tras leer el fichero, tenemos una lista de textos con formato JSON que podemos
    # descomponer. Asumimos que cada id de tweeter es unico por lo que puede usarse
    # como clave en un diccionario final:
    tweetsAnalizar = {}
    for tweet in tweetsDatos:
        try: jsonDict = json.loads(tweet)
        except: jsonDict = None
        if 'text' in jsonDict.keys():
            tweetsAnalizar[jsonDict['id']]=jsonDict['text'] 
    return tweetsAnalizar

def obtenerSentimientos(ficheroSentimientos):
    # Devuelve un diccionario asociando a cada sentimiento su valor
    fichero = open(ficheroSentimientos)
    listaSentimientos = fichero.readlines()
    # Basandonos en la estructura, en cada elemento de la lista hay una cadena de dos
    # palabras separadas por un tabulador \t --> Generamos un diccionario para 
    # explotarlo mejor
    sentimientosDict = {}
    for sentimiento in listaSentimientos:
        listaFila = sentimiento.split('\t')
        sentimientosDict[listaFila[0]] = int(listaFila[1])
    return sentimientosDict

def obtenerSentimientosTweets(ficheroSentimientos, ficheroTweets):
    # Devuelve un diccionario donde las claves son los ids de tweets y los valores
    # son un diccionario con 'texto', 'sentimiento' y 'valoracion'
    # Primero obtenemos los tweets en lista de diccionarios y el diccionario
    # de palabras con sus valores de sentimiento
    tweetsAnalizar = obtenerTweetsConTexto (ficheroTweets)
    sentimientosAplicar = obtenerSentimientos(ficheroSentimientos)
    # Recorrer cada tweet buscando todos los sentimientos que pueda tener y aplicar
    # la suma de sus valores. 
    sentimientosDict = {}
    for tweet in tweetsAnalizar:
        # Dado que los sentimientos pueden contener espacios, usamos find, en lugar 
        # de splitear y buscar por keys:
        valorSentimiento = 0
        listaSentimientos = []
        for sentimiento in sentimientosAplicar:
            if (tweetsAnalizar[tweet].find(' '+sentimiento+' ') >= 0 # Palabra completa
              or tweetsAnalizar[tweet].find(sentimiento+' ') == 0 # Primera palabra
              or tweetsAnalizar[tweet].find(' '+sentimiento, len(tweetsAnalizar[tweet]) - len(' '+sentimiento), len(tweetsAnalizar[tweet])) >= 0 # Ultima palabra
               ):
                listaSentimientos = listaSentimientos + [sentimiento + ' ' + str(sentimientosAplicar[sentimiento])]
                valorSentimiento = valorSentimiento + sentimientosAplicar[sentimiento]
        # print(tweet,tweetsAnalizar[tweet], valorSentimiento, listaSentimientos)
        sentimientosDict[tweet] = { 'texto':tweetsAnalizar[tweet], 'sentimiento':valorSentimiento, 'valoracion':listaSentimientos }
    return sentimientosDict

# %%
ficheroTweets = '/home/chema/MasterBI/practicas/01.Fundamentos/salida_tweets.txt'
ficheroSentimientos = '/home/chema/MasterBI/practicas/01.Fundamentos/Sentimientos.txt'
# tweetsAnalizar = obtenerTweetsConTexto (ficheroTweets)
# kk = obtenerSentimientos(ficheroSentimientos)
resultado = obtenerSentimientosTweets(ficheroSentimientos, ficheroTweets)
for idTweet in resultado:
    print(idTweet, 'sentimiento = ' + str(resultado[idTweet]['sentimiento']))
    # Si se quiere ver texto o explicacion del valor del sentimiento:
    print(idTweet, resultado[idTweet])
# pythonDatos['id']
# pythonDatos['text']
# Out:
# 509748524897292288 sentimiento = 0
# 509748524897292288 {'texto': '@Brenamae_ I WHALE SLAP YOUR FIN AND TELL YOU ONE LAST TIME: GO AWHALE', 'sentimiento': 0, 'valoracion': []}
# 509748529070616576 sentimiento = 0
# 509748529070616576 {'texto': 'Metin Şentürk Twitterda @metinsenturk MUHTEŞEM ÜÇLÜ; SEN, BEN, MÜZİK', 'sentimiento': 0, 'valoracion': []}
# 509748529095774208 sentimiento = 0
# 509748529095774208 {'texto': 'RT @byunghns: 😭 I LOVE #틴탑 SO MUCH #쉽지않아 IS GOING TO BE SO GOOD 😭', 'sentimiento': 0, 'valoracion': []}
# 509748529104175104 sentimiento = 0
# 509748529104175104 {'texto': 'que hdp maicon lo que le hizo a david luiz jajajajajajajajajajaj,igual se jodio la carrera', 'sentimiento': 0, 'valoracion': []}
# 509748529107988480 sentimiento = 0
# 509748529107988480 {'texto': 'ドライ！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！', 'sentimiento': 0, 'valoracion': []}
# 509748529074814976 sentimiento = 0
# 509748529074814976 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529074827266 sentimiento = 0
# 509748529074827266 {'texto': 'RT @GossipRoomOff: Si Nathalie sait pertinemment que son couple ne va pas durer, alors pourquoi accepter la demande en mariage de Vivian ? …', 'sentimiento': 0, 'valoracion': []}
# 509748529083211776 sentimiento = 0
# 509748529083211776 {'texto': 'RT @Dayannalozano_: Junior va perdiendo... http://t.co/5mOsR7boLx', 'sentimiento': 0, 'valoracion': []}
# 509748529074823170 sentimiento = 0
# 509748529074823170 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529087397889 sentimiento = 0
# 509748529087397889 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529104191488 sentimiento = 0
# 509748529104191488 {'texto': 'الله أكبر الله أكبر الله أكبر, لا إله إلا الله, الله أكبر الله اكبر ولله الحمد http://t.co/M454OhQpYY', 'sentimiento': 0, 'valoracion': []}
# 509748529074827267 sentimiento = 0
# 509748529074827267 {'texto': "TWİTTER'I AKRABALAR KEŞFEDİCEK DİYE ÇOK KORKUYORUM \n Metin Şentürk Twitterda @metinsenturk", 'sentimiento': 0, 'valoracion': []}
# 509748529070632960 sentimiento = 0
# 509748529070632960 {'texto': 'RT @PINKBATHARRY: les saintes nitouches de ma classe qui aiment les 5sos si je leur montre le vine de la bite a calum on verra si elles son…', 'sentimiento': 0, 'valoracion': []}
# 509748529104162816 sentimiento = 0
# 509748529104162816 {'texto': "RT @le_Parisien: Ebola\xa0: des pilotes d'Air France refusent les vols vers les pays touchés http://t.co/lt37QKDwr2", 'sentimiento': 0, 'valoracion': []}
# 509748529087381504 sentimiento = -3
# 509748529087381504 {'texto': "@hailee_danielsx I'm not mean cuz I'm ugly so ya", 'sentimiento': -3, 'valoracion': ['ugly -3']}
# 509748529070612481 sentimiento = 5
# 509748529070612481 {'texto': 'You better believe your beautiful', 'sentimiento': 5, 'valoracion': ['beautiful 3', 'better 2']}
# 509748529083191296 sentimiento = 0
# 509748529083191296 {'texto': "RT @baileymac02: CAN'T WAIT! I am playing @SoccerSix at The London Soccerdome on SUNDAY 26TH OCTOBER! Tickets selling fast: http://t.co/c6i…", 'sentimiento': 0, 'valoracion': []}
# 509748529079009280 sentimiento = 0
# 509748529079009280 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529074417666 sentimiento = 0
# 509748529074417666 {'texto': 'ドラコ・マルフォイ\u3000「闇の帝王が支配なさる時、OWLやNEWTが何科目なんて『あの人』が気になさるか？もちろん、そんなことは問題じゃない・・・『あの人』のためにどのように奉仕し、どのような献身ぶりを示して来たかだけが重要だ」', 'sentimiento': 0, 'valoracion': []}
# 509748529086996481 sentimiento = 0
# 509748529086996481 {'texto': 'RT @reading_bot_: 마주앉는다는 것은 눈으로 보기를 좋아한다는 것이다.\n옆에 앉는다는 것은 손으로 만지기를 좋아한다는 것이다.\n그러니까 남자들은 시각 중심적이고\n여자들은 촉각 혹은 후각 중심적이다.\n(이문재, 아주 낯선 낯익은 이야기)', 'sentimiento': 0, 'valoracion': []}
# 509748529074417665 sentimiento = 0
# 509748529074417665 {'texto': 'RT @En7raaF69: عبودي من الرياض ينآك آآح يالدلع\n\nhttp://t.co/HS1h0xwPAo\n\n#افلام_سكس #ممحونه #ورعان #سكس #ديوث #سالب #قحبه #خلفي #فلم #محارم …', 'sentimiento': 0, 'valoracion': []}
# 509748529095389184 sentimiento = 0
# 509748529095389184 {'texto': 'Vince Staples so cold', 'sentimiento': 0, 'valoracion': []}
# 509748529095782400 sentimiento = 0
# 509748529095782400 {'texto': '@Chinamiiii721 \n\n球児？\nわからんか\n\nもう一人の方は？あのギャル見たいな子', 'sentimiento': 0, 'valoracion': []}
# 509748529079005184 sentimiento = 0
# 509748529079005184 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529074413568 sentimiento = 0
# 509748529074413568 {'texto': "'", 'sentimiento': 0, 'valoracion': []}
# 509748529087397891 sentimiento = 0
# 509748529087397891 {'texto': '#AbrahamMateoEnCanalFiesta @dominguezja Necesito que me susure al oido, abrazarlo, sentir su calor.. TODO LO QUE SIEMPRE E DESEADO!.P', 'sentimiento': 0, 'valoracion': []}
# 509748529074810880 sentimiento = 0
# 509748529074810880 {'texto': '@AppIe_France mais ne vs sentez pas agressé, même non officiel votre compte est intéressant car rassemble les différentes infos.', 'sentimiento': 0, 'valoracion': []}
# 509748529074827265 sentimiento = 0
# 509748529074827265 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529087406080 sentimiento = 0
# 509748529087406080 {'texto': 'http://t.co/Chp71M0uCe', 'sentimiento': 0, 'valoracion': []}
# 509748529087393792 sentimiento = 6
# 509748529087393792 {'texto': "RT @Nashgrier: Happy Birthday to one of my best friends @jackgilinsky Can't wait till you're out in LA! Have a good one!", 'sentimiento': 6, 'valoracion': ['best 3', 'good 3']}
# 509748529070219264 sentimiento = 2
# 509748529070219264 {'texto': 'I liked a @YouTube video from @jordzcreations http://t.co/YJhzCimXHG TOP 5 RATED PLAYERS IN FIFA15! (MESSI, RONALDO &amp; IBRA!)', 'sentimiento': 2, 'valoracion': ['liked 2']}
# 509748529108361217 sentimiento = 0
# 509748529108361217 {'texto': 'RT @KirkJTorrance: Cat\'s out of the bag! "@WilliamJHague: giving Scotland more powers if it votes No is not Government policy" http://t.co/…', 'sentimiento': 0, 'valoracion': []}
# 509748529082814464 sentimiento = 0
# 509748529082814464 {'texto': 'RT @NASA: Roiling flows of lava on Holuhraun Lava Field seen by @NASA_Landsat in Iceland: http://t.co/3ogFKIvcfv #EarthRightNow http://t.co…', 'sentimiento': 0, 'valoracion': []}
# 509748529070239744 sentimiento = 0
# 509748529070239744 {'texto': '続編きたあああ\u3000 #prismaillya', 'sentimiento': 0, 'valoracion': []}
# 509748529091207168 sentimiento = 0
# 509748529091207168 {'texto': '"@jaureguisteam: VOU TER QUE COMEÇAR COM AS AMEAÇAS  #MTVEMA #NominateFifthHarmony"', 'sentimiento': 0, 'valoracion': []}
# 509748529070612480 sentimiento = 0
# 509748529070612480 {'texto': 'http://t.co/EMQdW8bhKx', 'sentimiento': 0, 'valoracion': []}
# 509748529082806272 sentimiento = 0
# 509748529082806272 {'texto': 'RT @PBirdly: Just setting up my Twitter. #myfirstTweet', 'sentimiento': 0, 'valoracion': []}
# 509748529070624768 sentimiento = 0
# 509748529070624768 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529078616064 sentimiento = 0
# 509748529078616064 {'texto': 'RT @Dr_alqarnee: لست مسئولاً عن ذنوب الناس, فقط ابكِ على نفسك, ونُح على روحك (كُلُّ نَفسٍ بِمَا كَسَبَت رَهِينَةٌ).', 'sentimiento': 0, 'valoracion': []}
# 509748529104191489 sentimiento = 0
# 509748529104191489 {'texto': 'Kıskancım canım ben, başlatma kankana, kardeşine \n Metin Şentürk Twitterda @metinsenturk', 'sentimiento': 0, 'valoracion': []}
# 509748529083203585 sentimiento = 0
# 509748529083203585 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529074798592 sentimiento = 1
# 509748529074798592 {'texto': 'RT @disneywords: Dreams are as real as you want them to be. Dreams are as real as the sky and the sea. –Peter Pan (Disney Dreams)', 'sentimiento': 1, 'valoracion': ['want 1']}
# 509748529104158720 sentimiento = 0
# 509748529104158720 {'texto': 'RT @Ste1nkopf: http://t.co/PTMaE4L2mT Печать бланков', 'sentimiento': 0, 'valoracion': []}
# 509748529086996480 sentimiento = 0
# 509748529086996480 {'texto': "RT @a7laahm85: أميرت'ن م همّها لبس وعقوود\nصعب'ن على من حبّها مشتراها\n\nتذبح ب كثر الملح وعيونها السود\nوتقصر جميع الغيد عنّ مستواها\n🌹🌹أمجاد", 'sentimiento': 0, 'valoracion': []}
# 509748529083215873 sentimiento = 0
# 509748529083215873 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529108357120 sentimiento = 2
# 509748529108357120 {'texto': "@Aurinth I think it's possible, and sometimes scenes like that can work as long as they're bookended by some sort of development.", 'sentimiento': 2, 'valoracion': ['like 2']}
# 509748529074434048 sentimiento = 0
# 509748529074434048 {'texto': 'http://t.co/mFdtyT81ux', 'sentimiento': 0, 'valoracion': []}
# 509748529087401984 sentimiento = 0
# 509748529087401984 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529074806784 sentimiento = 0
# 509748529074806784 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529103785984 sentimiento = 0
# 509748529103785984 {'texto': '@elofwind 중소기업이라 잡무만 따로 뽑지는 않지만 면접때 막내는 이런것도 해야한다 분명히 말을 하고 뽑아도 그런말 들어본 적 없다는듯이 행동하는 애들이 점점 많아집니다.. -.- @misty8628', 'sentimiento': 0, 'valoracion': []}
# 509748529087004673 sentimiento = 0
# 509748529087004673 {'texto': 'みーせてーみせてどーぉかーみせてうんとがんばっちゃーう', 'sentimiento': 0, 'valoracion': []}
# 509748529095405569 sentimiento = 0
# 509748529095405569 {'texto': 'もうお昼の時間だね。話題は変わるよ。今日は色々朝から調べ物をしてたよ。ps２の薄型本体のやつが故障のせいか、どのディスクを入れても、[読み込み失敗しました]てでるから、SCEのサポートセンターに電話(面接の電話は？)して、修理に出す準備してたよ。早く治って欲しいや', 'sentimiento': 0, 'valoracion': []}
# 509748529070632961 sentimiento = -2
# 509748529070632961 {'texto': 'RT @JackAllTimeLow: I am drunk in my cab and @5SOS came on radio. I came too', 'sentimiento': -2, 'valoracion': ['drunk -2']}
# 509748529099587584 sentimiento = 0
# 509748529099587584 {'texto': 'RT @SoldierrOfAllah: Shaytaan makes sin attractive to us', 'sentimiento': 0, 'valoracion': []}
# 509748529108369408 sentimiento = 2
# 509748529108369408 {'texto': '@SingleJoCoffee I like to think i do everything like a rebellious poet.....', 'sentimiento': 2, 'valoracion': ['like 2']}
# 509748529074827264 sentimiento = 0
# 509748529074827264 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529095405570 sentimiento = 0
# 509748529095405570 {'texto': "RT @PointlessBlog: Who's ready for a horror gaming video!?", 'sentimiento': 0, 'valoracion': []}
# 509748529070604288 sentimiento = 0
# 509748529070604288 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748529104171008 sentimiento = 0
# 509748529104171008 {'texto': 'Chancho 🐷🐷🐷 http://t.co/lmytpEILGf', 'sentimiento': 0, 'valoracion': []}
# 509748529074823168 sentimiento = 0
# 509748529074823168 {'texto': 'RT @Sovainikita: @PallomaaGon Me manda o teu whats', 'sentimiento': 0, 'valoracion': []}
# 509748529107972096 sentimiento = 0
# 509748529107972096 {'texto': 'قال صلى الله عليه وسلم يا أيها الناس إن منكم منفرين فأيكم ما صلى بالناس فليوجز فإن فيهم الكبير والضعيف وذا الحاجة -- صحيح البخاري #Hadith', 'sentimiento': 0, 'valoracion': []}
# 509748529087004672 sentimiento = 0
# 509748529087004672 {'texto': '伊紙、先制アシストの長友をMOMに選出「一連の動きはパーフェクト」\nhttp://t.co/ut33gNIoY3\n長友はフル出場し、75分にマウロ・イカルディの先制点を右からのクロスでアシストした。 http://t.co/bUpYqLNFR6', 'sentimiento': 0, 'valoracion': []}
# 509748529087397890 sentimiento = 0
# 509748529087397890 {'texto': 'MUULHER SCRR %%%% PQPSGJFF http://t.co/v8FkLoo0P5', 'sentimiento': 0, 'valoracion': []}
# 509748529108373504 sentimiento = 0
# 509748529108373504 {'texto': '“@DJZeeti: twitpic a selfie that will get alot of retweets” http://t.co/Zlk66HAEOo', 'sentimiento': 0, 'valoracion': []}
# 509748529108353024 sentimiento = 0
# 509748529108353024 {'texto': 'RT @Positivamos: tudo o que eu quero é um amor sincero.', 'sentimiento': 0, 'valoracion': []}
# 509748533294284800 sentimiento = 0
# 509748533294284800 {'texto': 'xxx vids: Lovely chick Cameron Love hardcore teen sex #porn #followback #teen #itunes http://t.co/Sz4pcQ4L6n', 'sentimiento': 0, 'valoracion': []}
# 509748533273317376 sentimiento = 0
# 509748533273317376 {'texto': 'Metin Şentürk Twitterda @metinsenturk ÖYLEDE GÜZEL BÖYLEDE GÜZEL', 'sentimiento': 0, 'valoracion': []}
# 509748533290094592 sentimiento = 1
# 509748533290094592 {'texto': 'Need to get this fresh trim.. Can’t be boarding plane to more looking like struggle', 'sentimiento': 1, 'valoracion': ['fresh 1', 'like 2', 'struggle -2']}
# 509748533302689792 sentimiento = 0
# 509748533302689792 {'texto': 'Amaia necesito un certificado para mañana presentar al cole saludame xdd :) (@AmaiaMontero live on http://t.co/0ohHBjBvKf)', 'sentimiento': 0, 'valoracion': []}
# 509748533277495296 sentimiento = 0
# 509748533277495296 {'texto': 'http://t.co/qlQZMzZ49F', 'sentimiento': 0, 'valoracion': []}
# 509748533290090496 sentimiento = 0
# 509748533290090496 {'texto': 'yo dough! why she hit you?', 'sentimiento': 0, 'valoracion': []}
# 509748533290102784 sentimiento = 3
# 509748533290102784 {'texto': "Is this not the best idea we've thought of yet? #Dominos #Sandwich http://t.co/KYIBYZW9aV", 'sentimiento': 3, 'valoracion': ['best 3']}
# 509748533277503489 sentimiento = 0
# 509748533277503489 {'texto': 'RT @briflubia: http://t.co/3OHXwcQ12L... http://t.co/Tv1hgFjXEm', 'sentimiento': 0, 'valoracion': []}
# 509748533285904384 sentimiento = 0
# 509748533285904384 {'texto': 'Metin Şentürk Twitterda @metinsenturk Daha iyi olmaya çalışmayan iyi olarak ta kalamaz.', 'sentimiento': 0, 'valoracion': []}
# 509748533285494784 sentimiento = 0
# 509748533285494784 {'texto': 'ちょいまって日曜って今週の？', 'sentimiento': 0, 'valoracion': []}
# 509748533277499392 sentimiento = 0
# 509748533277499392 {'texto': 'If only I could put my thoughts into words', 'sentimiento': 0, 'valoracion': []}
# 509748533269114880 sentimiento = 0
# 509748533269114880 {'texto': 'RT @Elvinelol: World of #Warcraft Raiding Lengths by Expansion #WoW #PvE http://t.co/IKOKe02Heo', 'sentimiento': 0, 'valoracion': []}
# 509748533281705984 sentimiento = 0
# 509748533281705984 {'texto': 'RT @m199z: @Azooz201144 @mhmd350 @aser541 @zainsaudi @225_mg @sak5511 @ms3Ry_502 @aser2211 @aser5411 @abusaud20001 @V__I___P @Al3bdli_q8', 'sentimiento': 0, 'valoracion': []}
# 509748533277519873 sentimiento = 0
# 509748533277519873 {'texto': 'RT @JChristofides: p2p видео http://t.co/vh5EBRoa3h', 'sentimiento': 0, 'valoracion': []}
# 509748533302665216 sentimiento = 0
# 509748533302665216 {'texto': 'RT @1k305: 💞\u06dd💞\u06dd💞💎➊ #فرصتك✔💎➋ #لزيادة_متابعينك✔💎➌ #ريتويت✔♻💎➍ #فولومي✔💎➎ #فولوباك✔💎➏ #اضافة_من_عمل_ريتويت. 💞\u06dd💞\u06dd💞', 'sentimiento': 0, 'valoracion': []}
# 509748533285888000 sentimiento = 0
# 509748533285888000 {'texto': 'Assunto nas aulas: 1+1=2\nAssunto nas provas: qual o valor de x, se y é igual a distância do Sol com a Terra? 😒😱📖🙌', 'sentimiento': 0, 'valoracion': []}
# 509748533277503490 sentimiento = 0
# 509748533277503490 {'texto': 'due #MTVEMA  #NominateArianaGrande', 'sentimiento': 0, 'valoracion': []}
# 509748533272907777 sentimiento = 0
# 509748533272907777 {'texto': '@s_r_n__ \nせやん', 'sentimiento': 0, 'valoracion': []}
# 509748533277491200 sentimiento = 0
# 509748533277491200 {'texto': 'RT @FaizaMirza84: Dr #TUQ: 8 arab Rs is used daily on corruption in Pakistan\n\n#StatusQuoVsOppressed', 'sentimiento': 0, 'valoracion': []}
# 509748533268725760 sentimiento = 0
# 509748533268725760 {'texto': 'シラヌイだって38とかだからさぁ・・・', 'sentimiento': 0, 'valoracion': []}
# 509748533277503488 sentimiento = -2
# 509748533277503488 {'texto': "RT @cthagod: I keep making the mistake of talking to people who don't know what they are talking about.......", 'sentimiento': -2, 'valoracion': ['mistake -2']}
# 509748533264523264 sentimiento = 0
# 509748533264523264 {'texto': 'อยากกินบอนชอน อยากกินไก่ทอด อยากกินซุปกิมจิ อยากกินเกี๊ยวซ่า อยากกินทุกอย่างอ่ะตอนนี้ หิววววว...!!! 😭😂', 'sentimiento': 0, 'valoracion': []}
# 509748533302673408 sentimiento = 0
# 509748533302673408 {'texto': "-\nQUEIMAR A LINGUA NO CAFÉ &amp; UMA DAS PIORES COISAS :( :'( :(", 'sentimiento': 0, 'valoracion': []}
# 509748533293879296 sentimiento = 0
# 509748533293879296 {'texto': '@Raissawktkalex waooo i see ;;;;', 'sentimiento': 0, 'valoracion': []}
# 509748533289689088 sentimiento = 0
# 509748533289689088 {'texto': 'Скачала наконец то Сайлент хилл\nСупер город,у меня просто нет слов))', 'sentimiento': 0, 'valoracion': []}
# 509748533289709568 sentimiento = 0
# 509748533289709568 {'texto': 'わけわからんｗｗｗｗｗ ( @ayaka15fu 小声CAS。雑談 http://t.co/4Ny0qdtfUK )', 'sentimiento': 0, 'valoracion': []}
# 509748533289701376 sentimiento = 0
# 509748533289701376 {'texto': '293', 'sentimiento': 0, 'valoracion': []}
# 509748533285486592 sentimiento = 0
# 509748533285486592 {'texto': '@kiavess @ChilleDewd XD Shush', 'sentimiento': 0, 'valoracion': []}
# 509748533298073600 sentimiento = 0
# 509748533298073600 {'texto': 'RT @ZhArNTikA_: naif sekali, justru @sbyudhoyono g becus ngurus hkm krn bmasalah dg hkm @tm2000back 10. Harusn... http://t.co/3ALjecKx40', 'sentimiento': 0, 'valoracion': []}
# 509748533302288385 sentimiento = 0
# 509748533302288385 {'texto': '@yuxki @zibakurei_bot っしょァァ！', 'sentimiento': 0, 'valoracion': []}
# 509748533281300480 sentimiento = 0
# 509748533281300480 {'texto': '@chi_tanmama 浜松なうだよwww\n\n雷えぐい！！\n\nありがとー^ ^', 'sentimiento': 0, 'valoracion': []}
# 509748533298466816 sentimiento = 0
# 509748533298466816 {'texto': 'Van Morrison - Gloria &lt;3', 'sentimiento': 0, 'valoracion': []}
# 509748533298069504 sentimiento = 0
# 509748533298069504 {'texto': 'com.android.internal.os.ZygoteInit$MethodAndArgsCaller.run(ZygoteInit.java:1259)\nat (29/57)', 'sentimiento': 0, 'valoracion': []}
# 509748533277499393 sentimiento = 0
# 509748533277499393 {'texto': 'ขอเพิ่มเติมเกี่ยวกับความแตกต่าง และความสัมพันธ์เกี่ยวกับ Container กับ Codec นะครับ\nระบบนี้เกิดขึ้นในยุค Digital... http://t.co/mPZWZuZ8Eg', 'sentimiento': 0, 'valoracion': []}
# 509748533298495488 sentimiento = 0
# 509748533298495488 {'texto': 'RT @euhanjung: "@salvado10903734: http://t.co/BiZbCQ0QJR"~ Abandon greed~', 'sentimiento': 0, 'valoracion': []}
# 509748533281693696 sentimiento = 0
# 509748533281693696 {'texto': "Clothing &amp; Shoes &gt;&gt; Champion Textured Dazzle Men's Basketball Shorts - style 82619 #048 http://t.co/5GsFqGmxvn http://t.co/n99XginDGJ", 'sentimiento': 0, 'valoracion': []}
# 509748533264531456 sentimiento = 0
# 509748533264531456 {'texto': 'RT @laercioSoficial: ▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬\n★#CONNECT THE #WORLD★\n☑️INTEGRATION ☑️TEAM\n☀#TEAMFREE #FREE\n▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬\n#TFBJP  @Retweetsjp', 'sentimiento': 0, 'valoracion': []}
# 509748533264519170 sentimiento = 0
# 509748533264519170 {'texto': 'RT @LFCFaisal: الى الحين منب فاهم ليش ليفربول مو مثل باقي الاندية ؟ يصاب اللاعب ويرجع ويصاب مره ثانيه ولا نعرف كم مدة غيابه', 'sentimiento': 0, 'valoracion': []}
# 509748533281308672 sentimiento = 0
# 509748533281308672 {'texto': 'RT @aartic02: Victory of AAP will be Victory of Common People #OnlyAAP4Delhi', 'sentimiento': 0, 'valoracion': []}
# 509748533281697792 sentimiento = 0
# 509748533281697792 {'texto': 'Es imposible aguntar en mi casa.', 'sentimiento': 0, 'valoracion': []}
# 509748533264519168 sentimiento = 0
# 509748533264519168 {'texto': '"@utahjazz: Jeremy Ekans #NBAPokemon http://t.co/nzVBIQ3zk1" 😅😅😅😅', 'sentimiento': 0, 'valoracion': []}
# 509748533272924160 sentimiento = -1
# 509748533272924160 {'texto': "Why waste you time on someone when they don't give you any of their time", 'sentimiento': -1, 'valoracion': ['waste -1']}
# 509748533268733952 sentimiento = 0
# 509748533268733952 {'texto': 'Mgkin apa yg kau nak x diberi krn ada yg lbh baik sdg menanti. Berdoalah.', 'sentimiento': 0, 'valoracion': []}
# 509748533302263808 sentimiento = 0
# 509748533302263808 {'texto': 'RT @PBirdly: Just setting up my Twitter. #myfirstTweet', 'sentimiento': 0, 'valoracion': []}
# 509748533285486593 sentimiento = 0
# 509748533285486593 {'texto': 'أخت المعرس أول مايدخل اخوها الصالة: http://t.co/x5FtgBimhD', 'sentimiento': 0, 'valoracion': []}
# 509748533281705985 sentimiento = 0
# 509748533281705985 {'texto': 'RT @T1DFU: @sunshinexziall On a pas encore définis tous les lieux et dates, suis nos tweets on les tweetera bientôt', 'sentimiento': 0, 'valoracion': []}
# 509748533285502976 sentimiento = 0
# 509748533285502976 {'texto': '『Mステ\u3000スーパーライブ2013\u3000嵐、AKB48、ゴールデンボンバー、ももクロ、関ジャニ∞、Kis My Ft2、EXILE、MAN WITH A MISSION、前田敦子ら』 http://t.co/rEZ5kXfANC \n\n -YouTube -動画まとめ', 'sentimiento': 0, 'valoracion': []}
# 509748533289709570 sentimiento = -3
# 509748533289709570 {'texto': 'RT @connpost: #Milford school janitor arrested for leaving gifts, notes for student http://t.co/rjv7HybuFG', 'sentimiento': -3, 'valoracion': ['arrested -3']}
# 509748533285896192 sentimiento = 0
# 509748533285896192 {'texto': 'Me mueeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeero Por ir a desfilar -.-', 'sentimiento': 0, 'valoracion': []}
# 509748533289689089 sentimiento = 0
# 509748533289689089 {'texto': 'グラードンとカイオーガの新特性つよそう', 'sentimiento': 0, 'valoracion': []}
# 509748533285879808 sentimiento = 0
# 509748533285879808 {'texto': 'RT @TheBestOfTumbIr: http://t.co/QzUXmUxGrg', 'sentimiento': 0, 'valoracion': []}
# 509748533268725761 sentimiento = 0
# 509748533268725761 {'texto': 'RT @alkhaldi_ksa: #قطر_راعية_الارهاب\n\nاهلنا بالبحرين فتحوا العين عدل هالايام وخاصة من جهة البحر جنوب وجنوب شرقي', 'sentimiento': 0, 'valoracion': []}
# 509748533285883904 sentimiento = 0
# 509748533285883904 {'texto': 'Я ничего не боюсь, потому что у меня есть Хронометр Времени! С бонусами играть намного проще! http://t.co/UoB2xxnmnI #iPad #...', 'sentimiento': 0, 'valoracion': []}
# 509748537471795200 sentimiento = 0
# 509748537471795200 {'texto': '"@PointlessBlog: Who\'s ready for a horror gaming video!?" my body is ready', 'sentimiento': 0, 'valoracion': []}
# 509748537467633664 sentimiento = -2
# 509748537467633664 {'texto': 'Ur sick bud', 'sentimiento': -2, 'valoracion': ['sick -2']}
# 509748537484390401 sentimiento = 0
# 509748537484390401 {'texto': 'دعاء الغضب:أعوذ بالله من الشيطان الرجيم   http://t.co/igSq7clZ0q', 'sentimiento': 0, 'valoracion': []}
# 509748537463427072 sentimiento = 0
# 509748537463427072 {'texto': 'Dag 2 http://t.co/UUKPD2tN6d', 'sentimiento': 0, 'valoracion': []}
# 509748537467629568 sentimiento = 0
# 509748537467629568 {'texto': '@la12tuittera @americancloss alguien podría explicar el por qué? ?', 'sentimiento': 0, 'valoracion': []}
# 509748537471426560 sentimiento = 0
# 509748537471426560 {'texto': 'Now playing: Gaby Baginsky - Heute Morgen Immer Und  Ewig #on Schlagergarage', 'sentimiento': 0, 'valoracion': []}
# 509748537458827266 sentimiento = 0
# 509748537458827266 {'texto': 'Blunote.it | SVOLTA GROTTAGLIE, PIZZONIA NUOVO TECNICO http://t.co/KI7I6zoUaW', 'sentimiento': 0, 'valoracion': []}
# 509748537463435265 sentimiento = 0
# 509748537463435265 {'texto': 'RT @nouriaaajxo: 👌 http://t.co/5UgCEUbu6B', 'sentimiento': 0, 'valoracion': []}
# 509748537484406785 sentimiento = 0
# 509748537484406785 {'texto': 'Metin Şentürk Twitterda @metinsenturk Sen o kızı üzüyorsun ama o seni seviyor.', 'sentimiento': 0, 'valoracion': []}
# 509748537484390400 sentimiento = 0
# 509748537484390400 {'texto': '@tweetpotweet @RTS_Sport Bruka!!!', 'sentimiento': 0, 'valoracion': []}
# 509748537467215872 sentimiento = 0
# 509748537467215872 {'texto': 'عمره ١١ سنة ويكتب : ترى الجفاء بعد الوفاء عندنا عيب . \n\nاي جفاء واي وفاء ؟ اربع اغاني لام كلثوم \nاطول من حياتك "̮*beer* .', 'sentimiento': 0, 'valoracion': []}
# 509748537484386306 sentimiento = 0
# 509748537484386306 {'texto': 'RT @mmez11: للمتواجدين ⭕لمتابعة أكثر من[900 الف]مغرد ➊ فولو مي\xa0@mmez11\xa0➋ ريتويت ➌ فولو للي عمل رتويت ➍ فولو باك ➎ اللي ما يلتزم ما بيستفيد\xa0…', 'sentimiento': 0, 'valoracion': []}
# 509748537458823169 sentimiento = 0
# 509748537458823169 {'texto': 'やったー続編！', 'sentimiento': 0, 'valoracion': []}
# 509748537463414784 sentimiento = 0
# 509748537463414784 {'texto': '@4qh3_ 1o3q8ieshi', 'sentimiento': 0, 'valoracion': []}
# 509748537471406080 sentimiento = 0
# 509748537471406080 {'texto': '@mariam_63  entra aca y le ragalas UNOs 15 minutos de Votos a Lucero Xfa. Gracias !!! http://t.co/CLTKgmdxE8 #YSEA', 'sentimiento': 0, 'valoracion': []}
# 509748537488183296 sentimiento = -2
# 509748537488183296 {'texto': 'Sneezing like hell', 'sentimiento': -2, 'valoracion': ['hell -4', 'like 2']}
# 509748537463435264 sentimiento = 0
# 509748537463435264 {'texto': '@Belu_Cervantes jajaja.. felicidaaaaadeees tontula me acabo de enterar que aprobaste', 'sentimiento': 0, 'valoracion': []}
# 509748537479802880 sentimiento = 0
# 509748537479802880 {'texto': 'ஙே என்னாச்சி பழசு வது ஙே', 'sentimiento': 0, 'valoracion': []}
# 509748537496985600 sentimiento = 0
# 509748537496985600 {'texto': 'En el bus demos prioridad a niños,mujeres embarazadas, personas de la tercera edad y con discapacidad. Hagamos de Montería una #CiudadAmable', 'sentimiento': 0, 'valoracion': []}
# 509748537496977409 sentimiento = 0
# 509748537496977409 {'texto': "I just took a test where the answer to a question was Mozart's dad.", 'sentimiento': 0, 'valoracion': ['was 0']}
# 509748537471827969 sentimiento = 0
# 509748537471827969 {'texto': 'RT @MaxiiPoli: Iara es la mejor y me re ama', 'sentimiento': 0, 'valoracion': []}
# 509748537484394497 sentimiento = 9
# 509748537484394497 {'texto': 'RT @Louis_Tomlinson: The support for the new album and Fireproof has been amazing ! So so excited for you all to hear more ! Loveeeee', 'sentimiento': 9, 'valoracion': ['amazing 4', 'excited 3', 'support 2']}
# 509748537492385792 sentimiento = 2
# 509748537492385792 {'texto': 'No trato de ser mejor que nadie, trato de ser lo mejor que te ha sucedido en la vida.', 'sentimiento': 2, 'valoracion': ['ha 2']}
# 509748537475993600 sentimiento = 0
# 509748537475993600 {'texto': 'Metin Şentürk Twitterda @metinsenturk Pijamasını yere doğru çıkarıp, ayağı ile yukarıya fırlatıp tutanlar derneği...', 'sentimiento': 0, 'valoracion': []}
# 509748537467609089 sentimiento = 0
# 509748537467609089 {'texto': 'RT @EsppeonzAguirre: Ojo con las bananas...¡Arañas! ¡Yo prefiero los plátanos canarios!\nAdemás... Mejor sabor http://t.co/UcCsqGRq6E http:/…', 'sentimiento': 0, 'valoracion': []}
# 509748537484386305 sentimiento = 0
# 509748537484386305 {'texto': 'RT @Almusaffer: بعض الأشخاص عند حضوره يشعر الجمع بأنه اضفى على المكان رحابة وعلى الحضور راحة لسلوكه الرفيع وابتعاده عن الفظاظة والوقاحة وال…', 'sentimiento': 0, 'valoracion': []}
# 509748537467617280 sentimiento = 0
# 509748537467617280 {'texto': 'RT @ZodiacoHoy: #Sagitario Hoy recuerda que es bueno soñar pero es mucho mejor hacer, deja por un momento los sueños y empieza a hacerlos r…', 'sentimiento': 0, 'valoracion': []}
# 509748537475600384 sentimiento = 0
# 509748537475600384 {'texto': 'RT @Dodi_gigolo: Pin:2B1D7C60 dodi escort bot manly, yg mau di isep servis memuas kan stay di jak pus tlp 081317117763 http://t.co/inqo3skS…', 'sentimiento': 0, 'valoracion': []}
# 509748537496567808 sentimiento = 0
# 509748537496567808 {'texto': 'うおおおおおおおお！！', 'sentimiento': 0, 'valoracion': []}
# 509748537463406592 sentimiento = 0
# 509748537463406592 {'texto': 'Like omg 😍😍😍', 'sentimiento': 0, 'valoracion': []}
# 509748537467621376 sentimiento = 0
# 509748537467621376 {'texto': '@Thiagoarruee Vannn??', 'sentimiento': 0, 'valoracion': []}
# 509748537471823872 sentimiento = 0
# 509748537471823872 {'texto': 'Говорят, сегодня  День рождения нашего общего друга  -  Мэтью Ли (Мэтт Ли)!! \nДоброго здоровья, дорогой друг и... http://t.co/Z0PSetulYY', 'sentimiento': 0, 'valoracion': []}
# 509748537480208384 sentimiento = 0
# 509748537480208384 {'texto': "RT @onedirection: If you pre-order #1DAlbumFOUR from the 1D store, you'll get a wrist band on the day of release http://t.co/TDX9UJDLgU htt…", 'sentimiento': 0, 'valoracion': []}
# 509748537484386304 sentimiento = 0
# 509748537484386304 {'texto': 'RT @SemihKIZILTAN: FED, ZiraatBank soruşturmasını başlattı ve milyarca dolarlık ceza verebilir.\nBakarsınız seneye Ziraati BAsya satın alır\n…', 'sentimiento': 0, 'valoracion': []}
# 509748537471827970 sentimiento = 2
# 509748537471827970 {'texto': "@Mugsy4Fly LOL! But she's a famous twitter personality!!! (It was over Sarah Palin,who I really like - but don't think should run for POTUS)", 'sentimiento': 2, 'valoracion': ['like 2', 'was 0']}
# 509748537496989696 sentimiento = 0
# 509748537496989696 {'texto': '@Sarahcourcis ouai mais je vais courir la ! 😜💪', 'sentimiento': 0, 'valoracion': []}
# 509748537492373504 sentimiento = 0
# 509748537492373504 {'texto': 'RT @apuri_kamisama: 課金を無料に、\nこれ今はみんなやってますよww\n\nやらないと、損しかありませんw\n\n→http://t.co/dewahCkGoc\n\n馬鹿らしい課金は、卒業してくださいw http://t.co/W4UZSfkper', 'sentimiento': 0, 'valoracion': []}
# 509748537458827264 sentimiento = 0
# 509748537458827264 {'texto': '@_helloitsjo lmaoo ok I remeber you', 'sentimiento': 0, 'valoracion': []}
# 509748537479806977 sentimiento = 0
# 509748537479806977 {'texto': 'RT @dalidragibus1: Câlin http://t.co/uZMnaiChmp', 'sentimiento': 0, 'valoracion': []}
# 509748537471430657 sentimiento = 0
# 509748537471430657 {'texto': 'RT @m_alhtershi: أتمنى من جماهير عميد الأندية،،\n\nاغلاق موضوع المدرب الجديد(مؤقتاً)،، \n\nلمابعد مبارتنا مع العروبة،،\n\nنقاط العروبة مهمة جداً …', 'sentimiento': 0, 'valoracion': []}
# 509748537484394498 sentimiento = 0
# 509748537484394498 {'texto': 'RT @1967denberi: Alanzinho - Jaja - Yattara \n\n#Trabzonspor http://t.co/9HIL7G7NBW', 'sentimiento': 0, 'valoracion': []}
# 509748537496969216 sentimiento = 0
# 509748537496969216 {'texto': '@theMotherhood Thx for having us! #unstoppablemoms', 'sentimiento': 0, 'valoracion': []}
# 509748537458823168 sentimiento = 0
# 509748537458823168 {'texto': 'RT @1435P: ⭕ المتواجديــن ⭕ لزيادة متابعينكم ➊ فولومي ➋ ريتويت ➌ فولو اللي عمل ريتويت ➍ فولو باك ➎ اتبعوا الخطوات السابقة لزيادة متابعينكم …', 'sentimiento': 0, 'valoracion': []}
# 509748537492791296 sentimiento = 0
# 509748537492791296 {'texto': '@Belen_Chaya jajaja dije lo missmo', 'sentimiento': 0, 'valoracion': []}
# 509748537496965120 sentimiento = 0
# 509748537496965120 {'texto': 'せっかくワンピース持ってきたから着ようかな。アクセサリーも。', 'sentimiento': 0, 'valoracion': []}
# 509748537492783104 sentimiento = 0
# 509748537492783104 {'texto': 'RT @World_Images_: Can you give me a little push? http://t.co/fpIoAady2s', 'sentimiento': 0, 'valoracion': []}
# 509748537471410176 sentimiento = 0
# 509748537471410176 {'texto': 'RT @Arab_Panorama: بالسينما يقبض الممثل ملايين\n كذلك المخرج والممتج المستفيد الاكبر,\nأما بفليم داعش\nالمخرج السيناريست والمنتج\nخسروا\nلان الم…', 'sentimiento': 0, 'valoracion': []}
# 509748537488207872 sentimiento = 0
# 509748537488207872 {'texto': '@SoccerSeki824 まあ、そこら辺はまた（笑）', 'sentimiento': 0, 'valoracion': []}
# 509748537492402176 sentimiento = 0
# 509748537492402176 {'texto': 'ニルヴァーシュが２時をお伝え！', 'sentimiento': 0, 'valoracion': []}
# 509748537483993089 sentimiento = 0
# 509748537483993089 {'texto': '@anooood1401 سلام', 'sentimiento': 0, 'valoracion': []}
# 509748537467621377 sentimiento = 0
# 509748537467621377 {'texto': 'JUST AHHHHHH😍😍😍😍🙌😱😍😍😍 http://t.co/eAdv1R3u4j', 'sentimiento': 0, 'valoracion': []}
# 509748537463017472 sentimiento = 0
# 509748537463017472 {'texto': '@yuuna623815 え、なにしたん', 'sentimiento': 0, 'valoracion': []}
# 509748537458827265 sentimiento = 0
# 509748537458827265 {'texto': "RT @CHlLDHOODRUINER: Jay Z 44 and Beyoncé 32 so I'm not gonna stress it cause bae starts 1st grade tomorrow", 'sentimiento': 0, 'valoracion': []}
# 509748537483993088 sentimiento = 0
# 509748537483993088 {'texto': 'RT @laercioSoficial: ▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬\n★#CONNECT THE #WORLD★\n☑️INTEGRATION ☑️TEAM\n☀#TEAMFREE #FREE\n▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬\n#TFBJP  @Retweetsjp', 'sentimiento': 0, 'valoracion': []}
# 509748537484001280 sentimiento = 0
# 509748537484001280 {'texto': 'RT @QO_500: - وَقَدْ يَنْكَسِرُ بِالنَّفْسِ شَيء لا يَجْبرُهُ ألْفُ اعْتِذَار..', 'sentimiento': 0, 'valoracion': []}
# 509748537492377600 sentimiento = -6
# 509748537492377600 {'texto': '@Ru_ru50 ill beat that ass 19 times tonight 😉😏😘', 'sentimiento': -6, 'valoracion': ['ass -4', 'ill -2']}
# 509748537492402177 sentimiento = 0
# 509748537492402177 {'texto': 'RT @sandratorensma: http://t.co/Np9Z6LN95y', 'sentimiento': 0, 'valoracion': []}
# 509748537471827968 sentimiento = 0
# 509748537471827968 {'texto': 'RT @maamsalcatraz: Cette gomme la plus grosse arnaque du siècle elle était sensé gommé ls stylo ,mais elle déchirer la feuille cet pute htt…', 'sentimiento': 0, 'valoracion': []}
# 509748537458835456 sentimiento = 0
# 509748537458835456 {'texto': 'RT @missshosh4: اروع ما في السجود انك تهمس في اذن الأرض فيسمعك من في السماء♡', 'sentimiento': 0, 'valoracion': []}
# 509748537488203776 sentimiento = 0
# 509748537488203776 {'texto': 'RT @laercioSoficial: ▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬\n★#CONNECT THE #WORLD★\n☑️INTEGRATION ☑️TEAM\n☀#TEAMFREE #FREE\n▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬\n#TFBJP  @Retweetsjp', 'sentimiento': 0, 'valoracion': []}
# 509748537476022272 sentimiento = -1
# 509748537476022272 {'texto': 'RT @jmfmoran: Qué buena idea llamar al FBI. Total, EEUU no abusa de países a los que da ayuda policial, ¿cierto Colombia y México? http://t…', 'sentimiento': -1, 'valoracion': ['no -1']}
# 509748537476018176 sentimiento = 0
# 509748537476018176 {'texto': '@smallyson REBECA ME AJUDA EU TO COM FALTA DE AR E NÃO SEI ONDE TÁ MINHA BOMBINHA DE AR http://t.co/ebzyt4GZTh', 'sentimiento': 0, 'valoracion': []}
# 509748537496977408 sentimiento = 2
# 509748537496977408 {'texto': 'RT @onlyxibest: @LvBradshaw @Monarch544 it will be the highlight of my week #wino 🍷', 'sentimiento': 2, 'valoracion': ['highlight 2']}
# 509748541653549056 sentimiento = -2
# 509748541653549056 {'texto': "That's the downside of evening shift. When you work that day, your whole day revolves around it.", 'sentimiento': -2, 'valoracion': ['downside -2']}
# 509748541666103296 sentimiento = 0
# 509748541666103296 {'texto': 'Time going too fast.', 'sentimiento': 0, 'valoracion': []}
# 509748541653524480 sentimiento = 0
# 509748541653524480 {'texto': 'Müzik bitince bilgisayarın havalandırma sesiyle baş başa kalmak kadar boktan bir durum yok amk \n Metin Şentürk Twitterda @metinsenturk', 'sentimiento': 0, 'valoracion': []}
# 509748541691265025 sentimiento = 0
# 509748541691265025 {'texto': 'Agustina bigote te quiero mucho mucho waa. Valum estuvo acá √', 'sentimiento': 0, 'valoracion': []}
# 509748541687099392 sentimiento = 0
# 509748541687099392 {'texto': 'Sou apaixonada por garotos que amam animais 😍', 'sentimiento': 0, 'valoracion': []}
# 509748541657731072 sentimiento = 0
# 509748541657731072 {'texto': 'İnsan bazen kendi şanslarını kendi yaratıyor.ben öyle yaptım,kimseler yoktu yanımda. --Cihan Özdemir', 'sentimiento': 0, 'valoracion': []}
# 509748541666115584 sentimiento = 0
# 509748541666115584 {'texto': 'RT @TomiMondolo8: Solo entiende mi locura quien comparte mi pasión. cARc ★★☆★★', 'sentimiento': 0, 'valoracion': []}
# 509748541674512384 sentimiento = 0
# 509748541674512384 {'texto': 'Yıllarca ıssız bir adada mahsur kalmış gibi açım ilgiye. \n Metin Şentürk Twitterda @metinsenturk', 'sentimiento': 0, 'valoracion': []}
# 509748541687078913 sentimiento = 2
# 509748541687078913 {'texto': "We’re very proud to host tonight's “Evening With The Mayor” event at the Greystone Mansion. We are looking forward to seeing you there!", 'sentimiento': 2, 'valoracion': ['proud 2']}
# 509748541691277312 sentimiento = 0
# 509748541691277312 {'texto': 'Bazen hayatımı"canım şunu bi tutar mısın?"diye birine verip kaçasım geliyor.” \n Metin Şentürk Twitterda @metinsenturk', 'sentimiento': 0, 'valoracion': []}
# 509748541670313984 sentimiento = 0
# 509748541670313984 {'texto': 'jaa siel on Käläkärissä jo lunta @TMrjmki #nhlfi #KausiVoiAlkaa', 'sentimiento': 0, 'valoracion': []}
# 509748541682909185 sentimiento = 0
# 509748541682909185 {'texto': 'Turkey Strawberry Brie Sandwich, http://t.co/KCHkloO1jo http://t.co/g4629m6EkC', 'sentimiento': 0, 'valoracion': []}
# 509748541691281409 sentimiento = 0
# 509748541691281409 {'texto': "RT @bufnewspreptalk: Our #PrepTalkLive scoreboard page: Today's schedule, which is updated each night as scores are reported to us. http://…", 'sentimiento': 0, 'valoracion': []}
# 509748541666119680 sentimiento = -1
# 509748541666119680 {'texto': 'RT @TanPajeras: Pobre, se cree sirena y no llega a bagre.', 'sentimiento': -1, 'valoracion': ['no -1']}
# 509748541661921280 sentimiento = 0
# 509748541661921280 {'texto': '"@wordsporn: #wordsporn http://t.co/Of2E5SHGdN"', 'sentimiento': 0, 'valoracion': []}
# 509748541682876416 sentimiento = 0
# 509748541682876416 {'texto': 'Estas son las series que coparán la pequeña pantalla esta temporada #HoraPuntaMag http://t.co/SrQ5zV1F4Y http://t.co/5ykHVrZ84z', 'sentimiento': 0, 'valoracion': []}
# 509748541674516480 sentimiento = 0
# 509748541674516480 {'texto': 'Gracias rubia @Su_LaRubia , en breve haré una escapada a los madriles para ver a nuestro campeón de liga :-D. #teavisoytevienes ;-ppp', 'sentimiento': 0, 'valoracion': []}
# 509748541653544960 sentimiento = 0
# 509748541653544960 {'texto': '"@CMinIzuz:  Os dejo mi artículo, ¿Y Keylor?  http://t.co/4Td5V0KpW3."', 'sentimiento': 0, 'valoracion': []}
# 509748541691277313 sentimiento = 0
# 509748541691277313 {'texto': 'I think I am going to pre-order the #iPhone6Plus idk yet though', 'sentimiento': 0, 'valoracion': []}
# 509748541661519872 sentimiento = 0
# 509748541661519872 {'texto': 'Wrinkle in Time Late to watches, Apple set its own a minute early - Quartz: Fast CompanyWrinkle in Time Late t... http://t.co/LCszF8ArxD', 'sentimiento': 0, 'valoracion': []}
# 509748541661536256 sentimiento = 0
# 509748541661536256 {'texto': '中学のクラス対抗合唱大会みたいなやつで、歌う曲を決める投票で、「堀内孝雄の恋唄綴り」って書いて出したら先生に注意されたの思い出した。\n本気で歌いたくて友達と一緒に投票して2人とも怒られたw', 'sentimiento': 0, 'valoracion': []}
# 509748541661925376 sentimiento = 0
# 509748541661925376 {'texto': 'RT @Moda__Chicas: RT SI QUIERES ESTA TARTA POR TU CUMPLEAÑOS http://t.co/2a9it1mCCX', 'sentimiento': 0, 'valoracion': []}
# 509748541657341952 sentimiento = 0
# 509748541657341952 {'texto': '@kashiwaren0818 暇な日あそぼ！', 'sentimiento': 0, 'valoracion': []}
# 509748541686697984 sentimiento = 0
# 509748541686697984 {'texto': '@kirisoor おやすみなさい〜( ˘ω˘ )', 'sentimiento': 0, 'valoracion': []}
# 509748541666103297 sentimiento = 0
# 509748541666103297 {'texto': 'Buenas buenas buenas buenas buenas buenas buenas', 'sentimiento': 0, 'valoracion': []}
# 509748541682507776 sentimiento = 0
# 509748541682507776 {'texto': 'やったね3期うおおおおおおおおおおおおおおおおおおおおおおおおお #priya #prismaillya #2wei #tokyomx', 'sentimiento': 0, 'valoracion': []}
# 509748541674520576 sentimiento = 0
# 509748541674520576 {'texto': "RT @Max_Maillots: Ils ont mi la célébration de Eto'o dans #FIFA15, la mort !!\nhttp://t.co/gjKYCSZ4xK", 'sentimiento': 0, 'valoracion': []}
# 509748541657710592 sentimiento = 0
# 509748541657710592 {'texto': "@H109Z بحاول يعني D':", 'sentimiento': 0, 'valoracion': []}
# 509748541687083008 sentimiento = 0
# 509748541687083008 {'texto': 'RT @ChelseaBorrelli: Take me back to vaca http://t.co/QR9viwrGpn', 'sentimiento': 0, 'valoracion': []}
# 509748541653532672 sentimiento = 3
# 509748541653532672 {'texto': '@yomaira98x dude u have no idea how funny it was 😂', 'sentimiento': 3, 'valoracion': ['funny 4', 'no -1', 'was 0']}
# 509748541665705984 sentimiento = 0
# 509748541665705984 {'texto': 'Tidakkk rosakk speaker phone!! Huaaa!!!', 'sentimiento': 0, 'valoracion': []}
# 509748541666123776 sentimiento = 6
# 509748541666123776 {'texto': 'RT @PoetryPix: Retweet this tweet for a chance to win a small Lokai Bracelet. MUST BE FOLLOWING. Ends September 24th. http://t.co/C1lrUAsFlg', 'sentimiento': 6, 'valoracion': ['chance 2', 'win 4']}
# 509748541682483200 sentimiento = -1
# 509748541682483200 {'texto': "RT @C_Rivers24: @Calvinminds11 I'm honestly just chilling dude 😌", 'sentimiento': -1, 'valoracion': ['chilling -1']}
# 509748541653131264 sentimiento = 0
# 509748541653131264 {'texto': '@ren85247 うわ普通。やっぱSTR10000とかにしとこうかな', 'sentimiento': 0, 'valoracion': []}
# 509748541657731073 sentimiento = 0
# 509748541657731073 {'texto': 'RT @JaiBrooks1: #weloveyougavin @gavinontour http://t.co/lDyW7ZyWzM', 'sentimiento': 0, 'valoracion': []}
# 509748541657333761 sentimiento = 0
# 509748541657333761 {'texto': 'RT @vip_1h: ثلث الحكمة فطنة وثلثيها تغــــــافل - معاوية بن أبي سفيان❗️', 'sentimiento': 0, 'valoracion': []}
# 509748541653532674 sentimiento = 0
# 509748541653532674 {'texto': 'RT @JosDice: 🚐➕🎧 http://t.co/MHmiWdIyLQ', 'sentimiento': 0, 'valoracion': []}
# 509748541666131968 sentimiento = 0
# 509748541666131968 {'texto': 'DroidDia prime. Top Android Flow Chart Apps http://t.co/sQ9a2LH1AB #android  #app', 'sentimiento': 0, 'valoracion': []}
# 509748541657329664 sentimiento = 0
# 509748541657329664 {'texto': 'RT @gazoushu: なんだこのアプリｗ\n登録したらビッチから連絡きて\n連絡先交換してデートしてきたｗｗ\n\nしかも可愛すぎるしエロいし\n俺でもモテるとかｗｗ\n\nマジで一回DLしてみてくれｗｗ\n\n→http://t.co/LfHgdaeDlr http://t.co/5ax…', 'sentimiento': 0, 'valoracion': []}
# 509748541682880512 sentimiento = 0
# 509748541682880512 {'texto': 'Matemáticas, física... Nada fue hecho para mi 😭', 'sentimiento': 0, 'valoracion': []}
# 509748541653147649 sentimiento = 0
# 509748541653147649 {'texto': "@lxmharuka // Yas that's why i wonder", 'sentimiento': 0, 'valoracion': []}
# 509748541669928960 sentimiento = 0
# 509748541669928960 {'texto': '@if_eee この状況無理なので汗臭いジムにでも行ってくる。あ、女の子一人追加された。', 'sentimiento': 0, 'valoracion': []}
# 509748541657333760 sentimiento = 0
# 509748541657333760 {'texto': 'RT @hosoku3: 胸が大きい人は、思春期にいい恋をしていた人が多いそう。イイ恋でドバっと女性ホルモンが分泌された結果、胸が大きくなる。', 'sentimiento': 0, 'valoracion': []}
# 509748541674508288 sentimiento = -1
# 509748541674508288 {'texto': 'RT @augusto_rando: Si no sabías qué es la inflación ahora lo sabés http://t.co/7Hu1sjGnMh', 'sentimiento': -1, 'valoracion': ['no -1']}
# 509748541666123777 sentimiento = 0
# 509748541666123777 {'texto': 'RT @sosyalpencere: ETİKETİMİZ:\n#TurkishBanksUnderAttack\n#TurkishBanksUnderAttack\n#TurkishBanksUnderAttack\n#TurkishBanksUnderAttack\n#Turkish…', 'sentimiento': 0, 'valoracion': []}
# 509748541678317568 sentimiento = 7
# 509748541678317568 {'texto': '@JessicaFappit and the winner of the best lunchtime.visual goes to,,,,,,,', 'sentimiento': 7, 'valoracion': ['best 3', 'winner 4']}
# 509748541657739264 sentimiento = 0
# 509748541657739264 {'texto': '@thequintavious is unbelievable. Unbelievable how talented this kid is.', 'sentimiento': 0, 'valoracion': []}
# 509748541678682112 sentimiento = 0
# 509748541678682112 {'texto': '@glenisa10 you may be using more force than necessary', 'sentimiento': 0, 'valoracion': []}
# 509748541678694400 sentimiento = 0
# 509748541678694400 {'texto': '@Spartacat1 @Strykr916 @HoldfastGames HA *points and laughs* :P', 'sentimiento': 0, 'valoracion': []}
# 509748541653131266 sentimiento = 0
# 509748541653131266 {'texto': 'RT @congresskatni: @sanjaynirupam @aajtak yogi nahi abhiyogi hai Adityanath', 'sentimiento': 0, 'valoracion': []}
# 509748541653540864 sentimiento = 0
# 509748541653540864 {'texto': '@tvtelehit @barbaraig voto por BPM #SueñoSinFin en #TopPop ####1', 'sentimiento': 0, 'valoracion': []}
# 509748541690896384 sentimiento = 0
# 509748541690896384 {'texto': 'RT @maji_yabai: 亜久津がヤバイと思ったら千石がやばかったバトテニ読みたいよお～～～～～～～～～～～～～；；；', 'sentimiento': 0, 'valoracion': []}
# 509748541666103298 sentimiento = 0
# 509748541666103298 {'texto': '@PointlessBlog me🙋', 'sentimiento': 0, 'valoracion': []}
# 509748541678706688 sentimiento = 0
# 509748541678706688 {'texto': 'RT @emmyrossum: The Gallaghers. #season5 #SHAMELESS http://t.co/YPXGClqGl5', 'sentimiento': 0, 'valoracion': []}
# 509748541678682113 sentimiento = 0
# 509748541678682113 {'texto': 'RT @gonullu35: İsviçre o hesapları açıklayacak.\nAk mi kara mi hersey ortaya çıkacak.\n http://t.co/aZOxJLBFpV”', 'sentimiento': 0, 'valoracion': []}
# 509748541687078912 sentimiento = 0
# 509748541687078912 {'texto': "RT @Louis_Tomlinson: Can't wait for the new @EASPORTSFIFA .... Hurry upppp !!!!!!", 'sentimiento': 0, 'valoracion': []}
# 509748541678698496 sentimiento = 0
# 509748541678698496 {'texto': 'RT @emreayazjj: Demek lady gaga kostümü denedin. http://t.co/b5VNiLghYm', 'sentimiento': 0, 'valoracion': []}
# 509748541665726464 sentimiento = 0
# 509748541665726464 {'texto': '1度だけグーフィー好きになりたての頃に長いサイン貰ったなぁ(・ω・)', 'sentimiento': 0, 'valoracion': []}
# 509748541653147648 sentimiento = 0
# 509748541653147648 {'texto': 'RT @_hopehopes: เกลียดตัวเองที่โง่และขี้เกียจ', 'sentimiento': 0, 'valoracion': []}
# 509748541661921281 sentimiento = 0
# 509748541661921281 {'texto': 'Ariana grande😍 http://t.co/NzJPhxK16G', 'sentimiento': 0, 'valoracion': []}
# 509748541674512385 sentimiento = 0
# 509748541674512385 {'texto': 'RT @MAMBRU17: Termine mi sección de gym 💪 y práctica #preparacion #mundial2014 #italia #volleyball #dominicanteam… http://t.co/PkPtn9w4ib', 'sentimiento': 0, 'valoracion': []}
# 509748541686685697 sentimiento = 0
# 509748541686685697 {'texto': 'RT @apuri_kamisama: 課金を無料に、\nこれ今はみんなやってますよww\n\nやらないと、損しかありませんw\n\n→http://t.co/dewahCkGoc\n\n馬鹿らしい課金は、卒業してくださいw http://t.co/W4UZSfkper', 'sentimiento': 0, 'valoracion': []}
# 509748541653123072 sentimiento = 0
# 509748541653123072 {'texto': '長財布（小銭入れあり）部門でこれがランクインしたのか―【FRUTTI】ひとめ惚れ続出♪ 水彩画のようなレザーで仕立てるALBA Sereno（アルバ セレーノ）\u3000長財布\u3000花柄\u3000フルッティ http://t.co/G47lkhttCG', 'sentimiento': 0, 'valoracion': []}
# 509748541661908992 sentimiento = 1
# 509748541661908992 {'texto': 'Paint the town this weekend at @supercrawl! It’s easy to get to there with GO. http://t.co/2Zz0z72zDz #Supercrawl2014 http://t.co/rsQpACFL77', 'sentimiento': 1, 'valoracion': ['easy 1']}
# 509748541653135361 sentimiento = 0
# 509748541653135361 {'texto': '昨日ストーカーに殺されかける夢見たんだけど\n\n襲われてると殺されるの中間だからまあまあかな… 殺される夢は吉夢なんだね… http://t.co/WNvN8EdSUP', 'sentimiento': 0, 'valoracion': []}
# 509748541666127872 sentimiento = 1
# 509748541666127872 {'texto': 'Thank god for the GR skywalk!! #lakersthatdontwanttogetwet', 'sentimiento': 1, 'valoracion': ['god 1']}
# 509748541691265024 sentimiento = 0
# 509748541691265024 {'texto': 'Best person in the world.💕🌎🌻👯 http://t.co/nwuiiHLU07', 'sentimiento': 0, 'valoracion': []}
# 509748545852043265 sentimiento = 0
# 509748545852043265 {'texto': 'Lost my headphones , my day is over 😤😤', 'sentimiento': 0, 'valoracion': []}
# 509748545881407488 sentimiento = 1
# 509748545881407488 {'texto': 'People at my school think being gay is a choice but if being gay really is a choice why do most gay people including me want to die? pt.1', 'sentimiento': 1, 'valoracion': ['want 1']}
# 509748545852047360 sentimiento = 0
# 509748545852047360 {'texto': "@Peeweezzy exactly why a move would be considered a serious option. I'm going to the fútbol stadium now.😜", 'sentimiento': 0, 'valoracion': []}
# 509748545881399296 sentimiento = -1
# 509748545881399296 {'texto': 'things are hard', 'sentimiento': -1, 'valoracion': ['hard -1']}
# 509748545885581312 sentimiento = 0
# 509748545885581312 {'texto': 'Me zanima, če bo kakšna akcija za Šoštanj.', 'sentimiento': 0, 'valoracion': []}
# 509748545860407296 sentimiento = 0
# 509748545860407296 {'texto': 'De inveja eu não morro, mas mato muita gente. http://t.co/FhG1UYwW3U', 'sentimiento': 0, 'valoracion': []}
# 509748545847844864 sentimiento = 0
# 509748545847844864 {'texto': "RT @xJordaan37: Elle a dit oui mais pitié j'espère qu'il y'aura pas de cérémonie  #SS8", 'sentimiento': 0, 'valoracion': []}
# 509748545864609792 sentimiento = 0
# 509748545864609792 {'texto': '@Fco__Arevalo ahhhh chuta 😂 a cuanto? Regalamela entonces', 'sentimiento': 0, 'valoracion': []}
# 509748545881374720 sentimiento = -1
# 509748545881374720 {'texto': 'No olvide nada, solo deje de lado lo que ya no tenía arreglo👌', 'sentimiento': -1, 'valoracion': ['no -1']}
# 509748545877184512 sentimiento = 0
# 509748545877184512 {'texto': 'اللهم اغفر لي ذنبي ، ووسع لي في داري وبارك لي فيما رزقتني http://t.co/lsMaesqoLz', 'sentimiento': 0, 'valoracion': []}
# 509748545881407489 sentimiento = -2
# 509748545881407489 {'texto': "RT @Aliciabissiri: C'est dommage qu'elle dise a tout le monde que ça va pas durer... Sauf à Vivian.. #SS8", 'sentimiento': -2, 'valoracion': ['tout -2']}
# 509748545860427776 sentimiento = 0
# 509748545860427776 {'texto': 'RT@YouthH2O Whats on ur Back to Wellness Essentials list? RT if its energy, immunity, weighltoss &amp; skin glow #FabChat http://t.co/5OMPe97lFe', 'sentimiento': 0, 'valoracion': []}
# 509748545881399297 sentimiento = 0
# 509748545881399297 {'texto': 'غَربِل حبايبك بالغِياب .. ~', 'sentimiento': 0, 'valoracion': []}
# 509748545885577216 sentimiento = 3
# ...
# 509748550045925376 sentimiento = 3
# 509748550045925376 {'texto': 'Being with you is like having every single one of my wishes come true.', 'sentimiento': 3, 'valoracion': ['like 2', 'wishes 1']}
# 509748550054707202 sentimiento = 0
# 509748550054707202 {'texto': 'Nicole Moudaber - In The Mood 020 - 10-SEP-2014 - http://t.co/gcrpEKpHG6', 'sentimiento': 0, 'valoracion': []}
# 509748550041731072 sentimiento = -2
# 509748550041731072 {'texto': '@Pplschamp2310 At the very least. Her body count has certainly caused the most problems for the club. #SonsOfAnarchy', 'sentimiento': -2, 'valoracion': ['problems -2']}
# 509748550067322880 sentimiento = 0
# 509748550067322880 {'texto': 'Food &amp; Ryhmes for thought for the common tweeps @HitsNotHomework @MissMandii', 'sentimiento': 0, 'valoracion': []}
# 509748550071488513 sentimiento = -1
# 509748550071488513 {'texto': 'RT @ChochoMartinez1: Cami mientras me cagaba a pedo ,  la abrazaba y no la dejaba ir jajajajaja n.n', 'sentimiento': -1, 'valoracion': ['no -1']}
# 509748550054318080 sentimiento = 0
# 509748550054318080 {'texto': 'RT @omoro_ojisan: 【前の車を煽った結果⇒急停車、中からヤクザみたいのが降りてきて人生史上最大の修羅場に…】\n\nやっぱりヤクザはキチガイなほど怖かった…\n\nヤクザの乗った車を煽ったら\nとんでもないことに！？\n⇒http://t.co/Ew8SA68eJa htt…', 'sentimiento': 0, 'valoracion': []}
# 509748550050533376 sentimiento = 0
# 509748550050533376 {'texto': 'RT @_ifr_: "اللهم لا تبتليني بحب من لا يستحق، ولا تجعلني ابتلاءً لقلب من يستحق، اللهم لا تجعلني مبلغ هم إنسان ولا تجعل أي إنسان مبلغ همي."', 'sentimiento': 0, 'valoracion': []}
# 509748550050131970 sentimiento = 0
# 509748550050131970 {'texto': '12/3/21@シソンヌじろう ルミネタ終わりでさとしと新宿で牛タンに舌鼓打って帰宅。 帰ってきたらさとしの幼馴染の彼は相も変わらず股鼓を打ちながら爆睡中。 幼馴染でお笑いやってる、ってなんかいいわね。@向井 20年前から知ってる人。', 'sentimiento': 0, 'valoracion': []}
# 509748550058508288 sentimiento = 0
# 509748550058508288 {'texto': 'RT @akatyan2: 突然大人の表情になる赤ちゃん\n\nhttps://t.co/CN4jx9yKIh', 'sentimiento': 0, 'valoracion': []}
# 509748550062714881 sentimiento = 0
# 509748550062714881 {'texto': 'RT @sandratorensma: http://t.co/Np9Z6LN95y', 'sentimiento': 0, 'valoracion': []}
# 509748550045937664 sentimiento = 0
# 509748550045937664 {'texto': 'RT @Mo_nrm3: تاخذ من أوصاف الغزال التلفات \nوتأخذ من الصقر المبرقع عيونه\n\n من زينها لو يجمعون الملذات \nيبطون وصف الفاتنه ياصلونه" http://t.c…', 'sentimiento': 0, 'valoracion': []}
# 509748550066909184 sentimiento = 0
# 509748550066909184 {'texto': 'Destiny初日で売り上げ5億ドルかよ凄いな。', 'sentimiento': 0, 'valoracion': []}
# 509748550058917888 sentimiento = 0
# 509748550058917888 {'texto': 'Recién veo ese mensaje!', 'sentimiento': 0, 'valoracion': []}
# 509748550062702593 sentimiento = 0
# 509748550062702593 {'texto': '@nialls_lovexz @aMeezys_wiFey_ murgaa LOL\nhahaha', 'sentimiento': 0, 'valoracion': []}
# 509748550079893504 sentimiento = 0
# 509748550079893504 {'texto': 'RT @sergioaruizh: Lo malo de las mentes cerradas, es que vienen con bocas abiertas.', 'sentimiento': 0, 'valoracion': []}
# 509748550062706688 sentimiento = 0
# 509748550062706688 {'texto': '132', 'sentimiento': 0, 'valoracion': []}
# 509748550079897600 sentimiento = 0
# 509748550079897600 {'texto': '@NourhanIsmail97 MH we lolo we 2 mesh hat3rfyhom', 'sentimiento': 0, 'valoracion': []}
# 509748550054727681 sentimiento = 0
# 509748550054727681 {'texto': 'RT @TuiteiEmoticons: ❄  ❄ ❄\u3000\u3000 ❄ ❄❄\n❄\u3000\u3000   ❄\u3000❄\u3000\u3000  ❄\n❄\u3000\u3000\u3000\u3000❄\u3000\u3000\u3000\u3000❄\n❄\u3000\u3000                 \u3000\u3000 ❄\n\u3000❄\u3000    FRIO         ❄\n\u3000\u3000❄\u3000\u3000\u3000\u3000\u3000❄\n\u3000\u3000\u3000❄\u3000\u3000\u3000❄\n\u3000\u3000\u3000\u3000❄\u3000❄\n\u3000\u3000\u3000…', 'sentimiento': 0, 'valoracion': []}
# 509748550062714880 sentimiento = 0
# 509748550062714880 {'texto': 'RT @sekai_syogeki: 宮根誠司、激怒！ミヤネ屋生放送中にスタッフからカンペとりあげブチ切れｗｗｗ（動画\n\u3000\u3000http://t.co/lPnfik4FXU\n\n. http://t.co/Alh5LYcdP3', 'sentimiento': 0, 'valoracion': []}
# 509748550062702592 sentimiento = 0
# 509748550062702592 {'texto': 'RT @Ayed_Alosaimi: إذا رأيت متكبراً فاعلم أنه قليل الصلاة أو عديمها، لا يجتمع كبر مع كثرة سجود (سيماهم في وجوههم من أثر السجود) صح عن مجاهد…', 'sentimiento': 0, 'valoracion': []}
# 509748550042124289 sentimiento = 0
# 509748550042124289 {'texto': 'header ? 👀', 'sentimiento': 0, 'valoracion': []}
# 509748550079504384 sentimiento = 0
# 509748550079504384 {'texto': 'Después de 2 meses de que las entradas salieran a la venta, así va el #MalúCuartoPalacio @_MaluOficial_ 💃💃💃💃 http://t.co/boNW9zMZc4', 'sentimiento': 0, 'valoracion': []}
# 509748554261618688 sentimiento = 0
# 509748554261618688 {'texto': 'Aula só 15:15 agora', 'sentimiento': 0, 'valoracion': []}
# 509748554236448768 sentimiento = 0
# 509748554236448768 {'texto': 'Meryem ile bir dedikodu yaptık varya anlatamam :Dd \n Metin Şentürk Twitterda @metinsenturk', 'sentimiento': 0, 'valoracion': []}
# 509748554240651265 sentimiento = 0
# 509748554240651265 {'texto': 'nasıl olurda???Hâla bıkmadığım şarkı tadındasın..', 'sentimiento': 0, 'valoracion': []}
# 509748554244841472 sentimiento = 0
# 509748554244841472 {'texto': 'Hadi artık sen konuş, herkes sussun.. \n Metin Şentürk Twitterda @metinsenturk', 'sentimiento': 0, 'valoracion': []}
# 509748554236428288 sentimiento = 0
# 509748554236428288 {'texto': "i don't know what to get 9/11 for its birthday tomorrow", 'sentimiento': 0, 'valoracion': []}
# 509748554236444672 sentimiento = 0
# 509748554236444672 {'texto': '@BeyonceExplicit hello beyonce  ♥♥♥', 'sentimiento': 0, 'valoracion': []}
# 509748554249011200 sentimiento = 0
# 509748554249011200 {'texto': 'Seriously need some new boots', 'sentimiento': 0, 'valoracion': []}
# 509748554249019393 sentimiento = 0
# 509748554249019393 {'texto': 'Metin Şentürk Twitterda @metinsenturk Yoksa sizde sabahın ilk ışıklarını görmeden uyuyamayanlardan mısınız ?', 'sentimiento': 0, 'valoracion': []}
# 509748554249027584 sentimiento = 0
# 509748554249027584 {'texto': 'RT @BieberAnnual: 2 mins', 'sentimiento': 0, 'valoracion': []}
# 509748554269999104 sentimiento = 0
# 509748554269999104 {'texto': 'La entrada perfecta está entre los 2/3 y 3/4 del estadio, ni está tan vacío ni aperrado.', 'sentimiento': 0, 'valoracion': []}
# 509748554253209600 sentimiento = 0
# 509748554253209600 {'texto': 'RT @sonjimmons: Justin bieber http://t.co/YmHw1KwrBF', 'sentimiento': 0, 'valoracion': []}
# 509748554236440576 sentimiento = 0
# 509748554236440576 {'texto': 'RT @m_k_s_8: للمتواجدين الان \n✨⭕➊ فرصــتك الآن \n✨⭕➋ لزيادة متابعينك \n✨⭕➌ ريتويت \n✨⭕➍ فولومي\n✨⭕➎ فولوباك \n✨⭕➏ اضافة من عمل ريتويت 1 #الأهلى_…', 'sentimiento': 0, 'valoracion': []}
# 509748554257412096 sentimiento = 6
# 509748554257412096 {'texto': 'Happy Birthday to Robbie , @arsenalfantv you offer excellent insight &amp; coverage on The Mighty Arsenal hope you continue to expand &amp; Innovate', 'sentimiento': 6, 'valoracion': ['excellent 3', 'expand 1', 'hope 2']}
# 509748554240229376 sentimiento = 0
# 509748554240229376 {'texto': '@bakunyufujin \n\nオメーの電話番号はそれか違うのかどーなのかって聞いてんだろーがYO!それに答えりゃいーんだよ！', 'sentimiento': 0, 'valoracion': []}
# 509748554240651264 sentimiento = -3
# 509748554240651264 {'texto': 'When she says the dick gets better every time,,,,,,, I have no choice but to do the "daddy got stroke dance" a hahahaha', 'sentimiento': -3, 'valoracion': ['better 2', 'dick -4', 'no -1']}
# 509748554257408001 sentimiento = 0
# 509748554257408001 {'texto': 'Günlük Rapor: 47 kişi profilimi gezdi via (http://t.co/6VJqqqIKjM)', 'sentimiento': 0, 'valoracion': []}
# 509748554253238272 sentimiento = 4
# 509748554253238272 {'texto': 'Dear downstairs neighbros: 1:00 PM on a Wednesday is generally agreed upon as time not meant for turning up. But nice try.', 'sentimiento': 4, 'valoracion': ['agreed 1', 'nice 3']}
# 509748554265817088 sentimiento = 0
# 509748554265817088 {'texto': 'RT @yungthanatos: "whatchu been doing bro"  https://t.co/ALZxigLSSR', 'sentimiento': 0, 'valoracion': []}
# 509748554253205504 sentimiento = 0
# 509748554253205504 {'texto': 'RT @tab3na1: برمجيات جديده لدى مؤسسة تابعنا للتصميم والبرمجة وخدمات الويب', 'sentimiento': 0, 'valoracion': []}
# 509748554274205696 sentimiento = 0
# 509748554274205696 {'texto': 'Pose de viado, sem camisa, sorrindo, mordendo o lábio, sem calças, strip, modelo da CK, álbum novo em outubro é mt emoção pra uma pessoa', 'sentimiento': 0, 'valoracion': []}
# 509748554244444160 sentimiento = 0
# 509748554244444160 {'texto': 'ただひとつの', 'sentimiento': 0, 'valoracion': []}
# 509748554257399808 sentimiento = 0
# 509748554257399808 {'texto': 'Odeio qnd esqueço de enviar a msg. Daí fico q nem idiota achando que fui ignorada! 😒', 'sentimiento': 0, 'valoracion': []}
# 509748554274189314 sentimiento = 0
# 509748554274189314 {'texto': 'lçklçl', 'sentimiento': 0, 'valoracion': []}
# 509748554240237568 sentimiento = 0
# 509748554240237568 {'texto': '@miga_hisoka كلان كبير زي ميقا أكيد بيكون له حاقدين وبتواجهه عقبات واصلوا يامزز 3&gt;', 'sentimiento': 0, 'valoracion': []}
# 509748554261622784 sentimiento = 0
# 509748554261622784 {'texto': "Just hit some speed bumps but I'm not gonna let them bring me down. Just gonna regroup.", 'sentimiento': 0, 'valoracion': []}
# 509748554252816384 sentimiento = 0
# 509748554252816384 {'texto': '#JAGNATION #X 238', 'sentimiento': 0, 'valoracion': []}
# 509748554236063744 sentimiento = 0
# 509748554236063744 {'texto': 'RT @gyak615: @pink 다모아카지노✔ ＭＸ４４４４。ＣＯＭ ✔마닐라카지노로얄카지노태양성카지노★강남카지노다모아카지노강원카지노★베스트카지노썬시티카지노카지노잘하는법★타짜카지노서울카지노부산카지노사설카지노카지노베이크라운카지노★카지노팰리스카지노후기카지…', 'sentimiento': 0, 'valoracion': []}
# 509748554269601792 sentimiento = 0
# 509748554269601792 {'texto': '【定期】霊夢！主人公補正とか許さん！だいたい何やってもいいと浮かれてるから異変起こされるんだよ！恨めしい！', 'sentimiento': 0, 'valoracion': []}
# 509748554270003200 sentimiento = 0
# 509748554270003200 {'texto': 'WHY DOES MADDIE NEED LIKE A BAJILLION 5SOS SONGS. I AM LITERALLY THE ONE RESPONSIBLE TO GET THEm.', 'sentimiento': 0, 'valoracion': []}
# 509748554249039872 sentimiento = 2
# 509748554249039872 {'texto': "RT @Nashgrier: Happy birthday @tfionash I love you soooo much! Thank you for everything, you have no idea how much you mean to me. Hope it'…", 'sentimiento': 2, 'valoracion': ['love 3', 'no -1']}
# 509748554265395200 sentimiento = 0
# 509748554265395200 {'texto': 'RT @eglobalinfo: eGlobal Solutions | Coming Soon http://t.co/c6nGXQlVI1', 'sentimiento': 0, 'valoracion': []}
# 509748554273800195 sentimiento = 0
# 509748554273800195 {'texto': '(デング熱で学外休めるかな…)', 'sentimiento': 0, 'valoracion': []}
# 509748554253230080 sentimiento = 0
# 509748554253230080 {'texto': 'RT @dantyre: #INBOUND14! The Tuesday night parties are back! http://t.co/SelgGgFPdx', 'sentimiento': 0, 'valoracion': []}
# 509748554269614080 sentimiento = 0
# 509748554269614080 {'texto': 'มัน00.01ละ อีควาย', 'sentimiento': 0, 'valoracion': []}
# 509748554273800196 sentimiento = 0
# 509748554273800196 {'texto': 'Jangan berubah hanya karena cinta. Jika dia tak bisa menerima kekuranganmu, dia tak pantas dapat yg terbaik darimu.', 'sentimiento': 0, 'valoracion': []}
# 509748554274189312 sentimiento = 0
# 509748554274189312 {'texto': 'RT @FutboolFichajes: HAY FECHA!!\n\nReal Madrid-Barcelona jugarán el 25 de octubre a las 18hs España por la 9 jornada. http://t.co/hEER77gnzg', 'sentimiento': 0, 'valoracion': []}
# 509748554240647168 sentimiento = -1
# 509748554240647168 {'texto': "RT @katyperry: Don't forget @hernameisbanks debut record GODDESS came out today &amp; it is MAGNIFICENT! https://t.co/Ja42jyk9X7 #dontfuckwitha…", 'sentimiento': -1, 'valoracion': ['forget -1']}
# 509748554274189313 sentimiento = 0
# 509748554274189313 {'texto': 'http://t.co/tAUtZaheYZ yazn arkdşlr bnc', 'sentimiento': 0, 'valoracion': []}
# 509748554265788417 sentimiento = 0
# 509748554265788417 {'texto': 'I\'m sure they were up! Keep trying."@BotsBoyGeuk:@IsPhlyHoney :)will do!Tried them a little after I called u but I guess it was hella early.', 'sentimiento': 0, 'valoracion': ['was 0']}
# 509748554273792000 sentimiento = 4
# 509748554273792000 {'texto': 'RT @Tarunvijay: Popularly known as "Mahakavi Bharathiyar", he wrote on glory of the Tamil language, and odes to freedom fighters Tilak, Gan…', 'sentimiento': 4, 'valoracion': ['freedom 2', 'glory 2']}
# 509748554240643072 sentimiento = 3
# 509748554240643072 {'texto': 'RT @9GAG: My mood depends on how good my hair looks.', 'sentimiento': 3, 'valoracion': ['good 3']}
# 509748554269605888 sentimiento = 0
# 509748554269605888 {'texto': '368', 'sentimiento': 0, 'valoracion': []}
# 509748554273800192 sentimiento = 0
# 509748554273800192 {'texto': '@jeremiahtolbert @saladinahmed maybe it shoots jelly beans', 'sentimiento': 0, 'valoracion': []}
# 509748554240233472 sentimiento = 0
# 509748554240233472 {'texto': 'RT @fishnote: &lt;자산가 상위 10중 7은 구상금 한푼 안 내&gt;\n건강보험 구상금 미납자 중 고액자산가 상위 10명은 38억~135억원대의 부자~\n\n이들의 구상금 미징수율 80%대로\n전체 평균의 2배\n매해 120억원의 재정누수\nhttp://t…', 'sentimiento': 0, 'valoracion': []}
# 509748554257014784 sentimiento = 0
# 509748554257014784 {'texto': 'http://t.co/lbtoxOp5Gn - Tα ονόματα στη ΔΗΚΕΒΟ και στη ΔΕΥΑΒ :: Σιάτιστα http://t.co/ROqObR7CUU via @webnode', 'sentimiento': 0, 'valoracion': []}
# 509748554244452352 sentimiento = 2
# 509748554244452352 {'texto': "RT @NKsubs: Leeteuk: Yeaaa (gets up)\nKangin: Hyung, sit down. Really\nHeechul: Don't be like that to my friend!", 'sentimiento': 2, 'valoracion': ['like 2']}
# 509748554273792001 sentimiento = 0
# 509748554273792001 {'texto': '【自動】おやすみるきーヾ(･ω･o)', 'sentimiento': 0, 'valoracion': []}
# 509748554269986816 sentimiento = 0
# 509748554269986816 {'texto': 'RT @Gabriele_Corno: Natural History Museum @ London by Richard Beresford Harris #architecture #Prospective http://t.co/cWiBisJQDr', 'sentimiento': 0, 'valoracion': []}
# 509748554257018880 sentimiento = 0
# 509748554257018880 {'texto': '@_mjodcx تمم', 'sentimiento': 0, 'valoracion': []}
# 509748554261225472 sentimiento = 0
# 509748554261225472 {'texto': 'だめだ動けないなんてことだ', 'sentimiento': 0, 'valoracion': []}
# 509748554265792513 sentimiento = 0
# 509748554265792513 {'texto': 'RT @BestofCancer: #Cancer needs sincerity.', 'sentimiento': 0, 'valoracion': []}
# 509748554244431873 sentimiento = 0
# 509748554244431873 {'texto': 'RT @gazoushu: なんだこのアプリｗ\n登録したらビッチから連絡きて\n連絡先交換してデートしてきたｗｗ\n\nしかも可愛すぎるしエロいし\n俺でもモテるとかｗｗ\n\nマジで一回DLしてみてくれｗｗ\n\n→http://t.co/LfHgdaeDlr http://t.co/5ax…', 'sentimiento': 0, 'valoracion': []}
# 509748554261204993 sentimiento = 0
# 509748554261204993 {'texto': 'RT @30vs09: FA) 슈가군 브이！ㅎㅎ http://t.co/bXRDCriwOP', 'sentimiento': 0, 'valoracion': []}
# 509748554274181120 sentimiento = 0
# 509748554274181120 {'texto': 'A participar del Concurso Fotográfico Vélez 2014. Sin límite de edad ni equipamiento. Habrá dos categorías: Menores y Mayores.', 'sentimiento': 0, 'valoracion': []}
# 509748554240626688 sentimiento = 2
# 509748554240626688 {'texto': 'Just waking up in the morning gotta thank G O D ❤️❤️❤️❤️❤️🙏🙏', 'sentimiento': 2, 'valoracion': ['thank 2']}
# 509748554244841473 sentimiento = 0
# 509748554244841473 {'texto': 'RT @ThisIsYourEvent: فلل للبيع مساحات مختلفة\nفي غرب وشمال الرياض\n\nللمفاهمة 0551168155\n#داعش\n#عاجل\n#مؤتمر_الردة_في_جدة\n#الإسلام\n#فيلم', 'sentimiento': 0, 'valoracion': []}
# 509748554244816896 sentimiento = 0
# 509748554244816896 {'texto': 'RT @temasparamujer: 3 Consejos y asesoramiento para las rupturas matrimoniales http://t.co/gxZFbOAVk7', 'sentimiento': 0, 'valoracion': []}
# 509748554265415680 sentimiento = 0
# 509748554265415680 {'texto': 'RT @BLEACHmei: BLEACH好きな人RTふぁぼお願いします♪\n\n#BLEACH\n#RTした人フォローする http://t.co/opyqPkbmcE', 'sentimiento': 0, 'valoracion': []}
# 509748554248642561 sentimiento = 0
# 509748554248642561 {'texto': 'RT @hojimin31814: ไอจีแทยอนมีทุกอย่างจริงๆนะ ยกเว้นเจสสิก้า......', 'sentimiento': 0, 'valoracion': []}
# 509748554257022976 sentimiento = 0
# 509748554257022976 {'texto': 'RT @AL_shiratori: 【中毒性注意】納豆にちょい足しすると捗る禁断の廃人飯レシピまとめ\nhttp://t.co/AvYdduelou\n今年見た情報の中で一番ヤバいヤツだった', 'sentimiento': 0, 'valoracion': []}
# 509748554248642560 sentimiento = 0
# 509748554248642560 {'texto': 'RT @shinparu0330: ぱるる姫ウイルス拡散\u3000#ぱるる  #Paruru https://t.co/k28xr2MdHg', 'sentimiento': 0, 'valoracion': []}
# 509748554236432384 sentimiento = 0
# 509748554236432384 {'texto': "FFC IP's Symbaloo - Ozbirn's Google Mix #FCSLearn #FFCSoar #alpartners @FFCSoar http://t.co/Ub2wkOWat8", 'sentimiento': 0, 'valoracion': []}
